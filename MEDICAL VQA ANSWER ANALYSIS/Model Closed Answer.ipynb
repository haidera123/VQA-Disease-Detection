# %% [markdown]
# ### **WHAT DOES THIS NOTEBOOK CONTAINS:**
#
# ## This Notebook is divided into three parts:
#
# #### **PART: 1 Question to Embedding**
# #### **PART: 2 Loading and Preparaing the dataset for the Model**
# #### **PART: 3 Making the Model**
#
#
# * This notebook does not contain the exact implementation of the Stacked Attention Network, but has been inspired from that paper and the slides that has been mentioned above, and there are drawbacks (because I was unaware of **attention layer** and it's implementation in TensorFlow 2.0, and hence used some simple **Dense** layers in those places)
#
# * This notebook starts from just loading data, which are mentioned as below:
# 1. **trainset.json**:
#
# Contains a list of following enteries:
#
#               * qid
#               * image_name
#               * image_organ
#               * answer
#               * answer_type
#               * question
#               * question_type
#               * phrase_type
# An example is: {"qid": 1, "image_name": "synpic54610.jpg", "image_organ": "HEAD", "answer": "Yes", "answer_type": "CLOSED", "question_type": "PRES", "question": "Are regions of the brain infarcted?", "phrase_type": "freeform"}
#
# 2. **VQA_RAD Image Folder** : This folder contains the images (in .jpg format), whose name are the qid (as mentioned in the trainset.json)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import gensim
from gensim.models.keyedvectors import KeyedVectors
model_path = r'./Copy of GoogleNews-vectors-negative300.bin.gz'            # Path where the model is stored
model_w2v = gensim.models.KeyedVectors.load_word2vec_format(model_path, binary=True)            # Loading the model using gensim

# %%
import json
import h5py
import numpy as np
import copy
from random import shuffle, seed
import sys
import os.path
import argparse
import glob
import numpy as np
import scipy.io
import pdb
import string
import h5py
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
import gensim
import json
import re
import cv2
import matplotlib.pyplot as plt



def extract_feat(doc):
  '''
    Input: A sentence
    Output : Word Embedding of the sentence 

    Note : In order to maintain uniformity in the word embedding of the question, I have used padding (which would be shown later) with a maximum length of 21 (since this
    is the longest length of the question in trainset_closed.json)
  '''
  feat = []

  for word in doc:
      try:
          feat.append(model_w2v[word])
      except:
          pass
  return feat

def tokenize(sentence):


    ''' Perform Tokenization '''
    return [i for i in re.split(r"([-.\"',:? !\$#@~()*&\^%;\[\]/\\\+<>\n=])", sentence) if i!='' and i!=' ' and i!='\n']

def prepro_question(imgs, method):
    # preprocess all the question
    print('example processed tokens:')

    '''
    Input: The question from trainset_closed.json
    Performs tokenization and lowering of the question
    Output: Embedded version of the question

    Note that: We have still not padded the questions, just for information each of the word will be a 300 Dimensional Vector,
    hence, the word vector (which will be obtained after padding) will be a (21,300) Dimensional
    '''
    for i,img in enumerate(imgs):
        s = img['question'].lower()
        if method == 'nltk':
            txt = word_tokenize(str(s).lower())
        else:
            txt = tokenize(s)
        img['processed_tokens'] = txt
        if i < 10: print(txt)
        if i % 1000 == 0:
            sys.stdout.write("processing %d/%d (%.2f%% done)   \r" %  (i, len(img), i*100.0/len(imgs)) )
            sys.stdout.flush()   
    return imgs

def get_top_answers(imgs, num_ans):

    """
    Print the questions and returns the time, one answer is repeated
    """
    counts = {}
    for img in imgs:
        try:
            ans = img['answer'].lower()  # If the string is a number, it would result into error
        except :
            ans = str(img['answer'])
        counts[ans] = counts.get(ans, 0) + 1

    cw = sorted([(count,w) for w,count in counts.items()], reverse=True)
    print('top answer and their counts:') 
    print('\n'.join(map(str,cw[:20])))
    
    vocab = []
    for i in range(min(num_ans,len(cw))):
        vocab.append(cw[i][1])

    return vocab[:num_ans]


manualMap = { 'none': '0', 'zero': '0', 'one': '1', 'two': '2', 'three':
                  '3', 'four': '4', 'five': '5', 'six': '6', 'seven': '7',
                  'eight': '8', 'nine': '9', 'ten': '10' }

imgs_train = json.load(open('./trainset_closed.json' , 'r'))      # Unnnecesarily, i have used the same file two times
num_ans = 1000
top_ans = get_top_answers(imgs_train, num_ans)                         
atoi = {w:i for i,w in enumerate(top_ans)}                   # Word : Count
itoa = {i:w for i,w in enumerate(top_ans)}                   # Count : Word
feat_dim = 300                                               # 300 Dimensional Vector
imgs_data_train = json.load(open('./trainset_closed.json' , 'r'))  # trainset_closed.json
num_ans = 10    # Even 1 should work fine, but I had taken reference from COCO dataset, and hence, 10 (10 represents the top 10 answers to a picture)
method = 'nltk'
max_length = 21                       # Max Length of the question
dir_path = "./QA"    # The path where we will be storing .h5 file
N = len(imgs_data_train)

image_path = './../VQA_RAD Image Folder'

def save_data():
    
 
        for i,img in enumerate(imgs_data_train):
            #print('X' , img['ques_id'])
            img_path = image_path+img['image_name']  

            s = img['question']
            print(i,s)   # Print the number and the question
            if method == 'nltk':
                try:
                    txt = word_tokenize(str(s).lower())
                except :
                    txt = str(s)
            else:
                    txt = tokenize(s)

            img['processed_tokens'] = txt            
            question_id = img['qid']
            feat = np.array(extract_feat(img['processed_tokens']))
            label_arrays = np.zeros((1, max_length, feat_dim), dtype='float32')
            label_length = min(max_length, len(feat)) # record the length of this sequence
            label_arrays[0, :label_length, :] = feat
            try:
                ans_arrays = atoi[img['answer'].lower()]
            except :
                ans_arrays = atoi[str(img['answer'])]

            f = h5py.File(os.path.join( dir_path , str(question_id) + '.h5'), "w")
            f.create_dataset("ques_train", dtype='float32', data=label_arrays)
            f.create_dataset("answers", dtype='uint32', data=ans_arrays)
            f.close()
        return    
 
data = save_data()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# top answer and their counts:
# (884, 'no')
# (828, 'yes')
# (6, 'heterogeneous')
# (6, 'flair')
# (5, 'white matter')
# (5, 'diffuse')
# (4, 'right')
# (4, 'pa')
# (4, 'left')
# (4, 'hyperintense')
# (4, 'asymmetric')
# (3, 'with contrast')
# (3, 'normal')
# (2, 'solid')
# (2, 'right side')
# (2, 'pleural effusion')
# (2, 'on top of the patient')
# (2, 'multilobulated')
# (2, 'medical process')
# (2, 'less dense')
# 0 Are regions of the brain infarcted?
# 1 Are the lungs normal appearing?
# 2 Is there evidence of a pneumothorax
# 3 Is this a MRI of the chest?
# 4 Is the trachea midline?
# 5 Is there evidence of an aortic aneurysm?
# 6 Is there blunting of the costovertebral angles?
# 7 Is there a pneumothorax?
# 8 Is there a fracture?
# 9 Is there swelling of the grey matter?
# 10 Is this an anterior posterior image?
# 11 Is this the brain?
# 12 Is there air under the diaphragm?
# 13 Is this a CT image?
# 14 Is this an anterior-posterior image
# 15 Is there a skull fracture pictured?
# 16 Are there >12 of ribs?
# 17 Is/Are the lungs normal size?
# 18 Is/Are there a rib fracture?
# 19 Is/Are there fracturing in the patient's ribs?
# 20 Is/Are the lung parenchyma abnormal?
# 21 Is/Are the lung parenchyma abnormal?
# 22 was the arterial contrast phase selected?
# 23 does this plane of section include the gastric cardia?
# 24 Is/Are there thickening in the patient's small bowel wall?
# 25 was this taken with good x ray penetration
# 26 Are the common ileac arteries and veins patent in this section?
# 27 Is/Are there patency in the patient's common iliac arteries and veins?
# 28 Are the common iliac vasculature open?
# 29 Is/Are there patency in the patient's common iliac vasculature?
# 30 Is the spleen normal size?
# 31 Is/Are the spleen normal size?
# 32 Is the size of the spleen normal?
# 33 Is/Are the spleen normal size?
# 34 Are there air fluid levels present in the small bowel?
# 35 Is/Are there air fluid levels in the patient's small bowel?
# 36 is there contrast material showing air-fluid levels in the small bowel
# 37 Is/Are there air fluid levels in the patient's small bowel?
# 38 Is/Are the mass located near/in the mid brain?
# 39 Is/Are the mass located near/in the mid brain?
# 40 Is the mass compressing the mid brain on this section?
# 41 Is there mass compression in the patient's midbrain?
# 42 Is the mass pushing on the midbrain structures?
# 43 Is there mass compression in the patient's midbrain?
# 44 Are brain structures shifted across the midline?
# 45 Is/Are there midline shift?
# 46 is there a midline shift of the cerebral parenchyma?
# 47 Is/Are there midline shift?
# 48 Is the gallbladder large in size?
# 49 Is/Are the gallbladder large?
# 50 Is the gallbladder distended?
# 51 Is/Are the gallbladder distended?
# 52 Are there >8 ribs shown in this image?
# 53 Are there >8 of the ribs?
# 54 Are there at least 8 ribs visible for good inspiratory effort?
# 55 Are there at least 8 of the ribs?
# 56 is this an image of the cerebellum
# 57 Is this a transverse section?
# 58 Is the patient's vertebral body indicative of normal aging?
# 59 any observed degenerative changes in the vertebral body?
# 60 Is/Are there degeneration in the patient's vertebral body?
# 61 Is/Are there obstruction in the patient's small bowel?
# 62 Is there evidence of herniation of the small bowel into the abdominal wall?
# 63 Is/Are there herniation in the patient's small bowel through the abdominal wall?
# 64 Is there evidence of an abdominal hernia?
# 65 Is/Are there herniation in the patient's small bowel through the abdominal wall?
# 66 Are there air-fluid levels present on this CT radiograph?
# 67 Is/Are there air fluid levels in the patient's bowel?
# 68 Is there evidence of air fluid levels in the patient's bowel?
# 69 Is/Are there air fluid levels in the patient's bowel?
# 70 Have brain structures crossed the midline of the brain?
# 71 Is/Are there midline shift?
# 72 Is there evidence of midlight shift of structures on this MRI?
# 73 Is/Are there midline shift?
# 74 was this taken in PA position?
# 75 Is there evidence of air in the peritoneum?
# 76 Is/Are there air in the patient's peritoneum?
# 77 Is there air in the peritoneal cavity?
# 78 Is/Are there air in the patient's peritoneal cavity?
# 79 Are the hilar soft tissue densities symmetric?
# 80 Is/Are there symmetry in the patient's hilums?
# 81 Are the soft tissue densities in the left hilum equivalent in size to the soft tissue densities in the right hilum?
# 82 Is/Are there equivalent size tissues densities in the patient's hilums?
# 83 Is the descending aortic silhouette of normal contour?
# 84 Is the descending aortic silhouette of normal contour and size?
# 85 Is there tortuosity of the descending aorta?
# 86 Is/Are there tortuosity in the patient's aorta?
# 87 Is the descending aortic silhouette of normal size?
# 88 Is/Are there tortuosity in the patient's aorta?
# 89 Is the descending aortic silhouette of normal size?
# 90 are the vertebral arteries patent in this section?
# 91 Are the vertebral arteries patent?
# 92 Are the vertebral arteries in view?
# 93 Is/Are there vertebral arteries?
# 94 Is/Are there hyper attenuating material in the patient's aorta?
# 95 Is/Are there calcifications in the patient's aorta?
# 96 Is the vertebro-basilar arterial network viewed in this section?
# 97 Is/Are there vertebral/basilar artery?
# 98 Is the vertebral artery/basilar artery located in this image?
# 99 Is/Are there vertebral/basilar artery?
# 100 Is there blurring of the grey-white matter junctions in the right temporal lobe?
# 101 Is/Are there blurring of the grey-white matter in the patient's right temporal lobe?
# 102 Is there no definitive border between the grey matter and white matter in the right temporal lobe?
# 103 Is/Are there blurring of the grey-white matter in the patient's right temporal lobe?
# 104 is there evidence of portal venous congestion?
# 105 Is/Are there portal venous congestion?
# 106 Is the portal vein engorged?
# 107 Is/Are there portal venous congestion?
# 108 is the plane of section transverse?
# 109 Is the liver parenchyma normal?
# 110 Is/Are the liver parenchyma normal?
# 111 Is the liver parenchyma homogenous?
# 112 Is/Are the liver parenchyma homogenous??
# 113 Is there no evidence of any hypo- or hyperattenuations located in the liver?
# 114 Is/Are the liver parenchyma homogenous??
# 115 Is the liver parenchyma homogenous and normal?
# 116 was this chest x ray taken in PA format?
# 117 Is the stomach thickening regular and uniform or ragged/asymmetrical?
# 118 How would you describe the stomach wall thickening?
# 119 Is the stomach wall thickening symmetric or asymmetric?
# 120 How would you describe the stomach wall thickening?
# 121 Is there evidence of ectopic tissue present in surrounding organs?
# 122 Is there metastatic tissue in the surrounding organs?
# 123 Is there evidence of metastatic tissue on organs surrounding the liver?
# 124 Is there metastatic tissue in the liver?
# 125 Are lung opacities noted?
# 126 Is/Are there nodules in the patient's lung?
# 127 is there evidence of intraparenchymal lung nodules?
# 128 Is/Are there nodules in the patient's lung?
# 129 Is/Are there air in the patient's peritoneal cavity?
# 130 Is/Are there air in the patient's peritoneal cavity?
# 131 Is/Are the heart size normal?
# 132 Is/Are the heart size normal?
# 133 Are there calcifications in the cerebral arteries?
# 134 Is/Are there calcifications in the patient's cerebral arteries?
# 135 Is there evidence of calcifications in the cerebral arteries?
# 136 Is/Are there calcifications in the patient's cerebral arteries?
# 137 Is there evidence of a right apical pneumothorax on this chest x-ray?
# 138 Is/Are there a pneumothorax in the patient's right lung?
# 139 Is a pneumothorax present near the right lung field?
# 140 Is/Are there a pneumothorax in the patient's right lung?
# 141 Are the branches of the superior mesenteric arteries filled with contrast?
# 142 Is/Are the superior mesenteric arteries hyperatenuated?
# 143 Are the branches of the superior mesenteric arteries hyper attenuated?
# 144 Is/Are the superior mesenteric arteries hyperatenuated?
# 145 Is/Are the heart narrowed?
# 146 Is/Are the heart narrowed?
# 147 Are there any fractures in any of the ribs?
# 148 Is/Are there fractures in the patient's ribs?
# 149 Are any of the patient's ribs fractured?
# 150 Is/Are there fractures in the patient's ribs?
# 151 Is there pulmonary edema
# 152 Is/Are the pulmonary vessels enlarged?
# 153 Is there evidence of fluid in the peritoneal cavity?
# 154 Is/Are there ascites?
# 155 Is there evidence of ascites?
# 156 Is/Are there ascites?
# 157 Has the small bowel perforated?
# 158 Is/Are there perforation in the patient's small bowel?
# 159 is there evidence of pneumoperitoneum?
# 160 Is this the small bowel on this image?
# 161 Is/Are the cardiac contour normal?
# 162 Are feces located in the colon?
# 163 Is/Are there stool in the patient's colon?
# 164 Is there stool in the colon?
# 165 Is/Are there stool in the patient's colon?
# 166 Do the left and right middle cerebral arteries appear patent on this section?
# 167 Is/Are there middle cerebral arteries?
# 168 Is the left and right MCA present?
# 169 Is/Are there middle cerebral arteries?
# 170 Is this a T2 weighted image?
# 171 Is the lesion causing significant brainstem herniation?
# 172 Is/Are there herniation in the patient's brainstem?
# 173 Is there herniation of the brainstem secondary to the lesion
# 174 Is/Are there herniation in the patient's brainstem?
# 175 is it difficult to delineate the left costophrenic angle?
# 176 Is/Are there blunting in the patient's left costophrenic angle?
# 177 Is there blunting of the left costophrenic angle?
# 178 Is/Are there blunting in the patient's left costophrenic angle?
# 179 Are structures associated with the midbrain located in this image?
# 180 Is/Are there midbrain structures?
# 181 Is the midbrain identified in this section?
# 182 Is/Are there midbrain structures?
# 183 Is/Are there pneumothorax in the patient's left lung field?
# 184 Is/Are there pneumothorax in the patient's left lung field?
# 185 Are there more than 5 enlarged (>1 cm) lymph nodes around the stomach
# 186 Are there >5 of lymph nodes near the stomach?
# 187 Are there >5 lymph nodes located near the stomach?
# 188 Are there >5 of lymph nodes near the stomach?
# 189 Does the gallbladder appear distended?
# 190 Is/Are the gallbladder enlarged?
# 191 Is the gallbladder enlarged?
# 192 Is/Are the gallbladder enlarged?
# 193 Is this image plane taken inferior to the liver?
# 194 is there any shift of midline structures visible in this section?
# 195 Is/Are there midline shift?
# 196 Is there shifting of structures across the middle?
# 197 Is/Are there midline shift?
# 198 Is/Are the right renal pelvis enlarged?
# 199 Is/Are the right renal pelvis enlarged?
# 200 Is there evidence of a small bowel obstruction with perforated viscus on this CT?
# 201 Is there pneumonperitoneum in the small bowel?
# 202 Is there evidence of a pneumoperitoneum secondary to a perforation?
# 203 Is there pneumonperitoneum in the small bowel?
# 204 Is there edema in the patient's right temporal lobe?
# 205 Is/Are there cytotoxic edema in the patient's right temporal lobe?
# 206 Is there evidence of cytotoxic edema in the right temporal lobe?
# 207 Is/Are there cytotoxic edema in the patient's right temporal lobe?
# 208 Does the mass have a smooth appearing border?
# 209 Is/Are the mass well-defined? -yes/no
# 210 Is the mass well-defined?
# 211 Is/Are the mass well-defined? -yes/no
# 212 Is there contrast in the colonic lumen?
# 213 Is/Are there contrast in the patient's colon?
# 214 Was the patient given oral contrast?
# 215 Is/Are there contrast in the patient's colon?
# 216 Is the celiac trunk visualized and patent?
# 217 Is the celiac trunk visualized?
# 218 Is/Are there visualization in the patient's celiac trunk?
# 219 Is the celiac trunk patent?
# 220 Is/Are there patency in the patient's celiac trunk?
# 221 Is the celiac trunk able to be visualized in this patient and is it open?
# 222 Is the celiac trunk able to be visualized in this patient?
# 223 Is/Are there visualization in the patient's celiac trunk?
# 224 Is the celiac trunk open?
# 225 Is/Are there patency in the patient's celiac trunk?
# 226 Is/Are there midline shift?
# 227 Is/Are there midline shift?
# 228 was this image taken without motion artifact
# 229 was this image taken with patient in symmetrical supine position?
# 230 Is/Are the left lung radioopaque?
# 231 Is/Are the left lung radioopaque?
# 232 Is this an image of the right and left temporal lobes?
# 233 Are the liver 	splee n	stomac h	and esophagus all visualized in this image?
# 234 Does the GI contrast hi-light the small bowel?
# 235 Is there oral contrast in the patient's small bowel?
# 236 Is/Are there contrast in the patient's small bowel?
# 237 Is there enlargement of the abdominal aorta on this image?
# 238 Is/Are the abdominal aorta large?
# 239 Is the abdominal aorta large in size?
# 240 Is/Are the abdominal aorta large?
# 241 Are the costophrenic angles sharp?
# 242 Is/Are there no blunting in the patient's costophrenic angles?
# 243 Is there no evidence of blunting of the costophrenic angles?
# 244 Is/Are there no blunting in the patient's costophrenic angles?
# 245 is the lung parenchyma well visualized?
# 246 Has the brainstem herniated?
# 247 Is/Are there herniation in the patient's brainstem?
# 248 is there evidence of brainstem herniation in this section
# 249 Is/Are there herniation in the patient's brainstem?
# 250 are the heart and lungs displayed well in this film
# 251 Is this image normal?
# 252 Is this image normal?
# 253 Any abnormal findings in the lower lung fields?
# 254 Is/Are there abnormalities in the patient's lower lung?
# 255 Are the lower lung fields normal?
# 256 Is/Are there abnormalities in the patient's lower lung?
# 257 Is the mass loculated?
# 258 Is/Are the mass located? -yes/no
# 259 Is there a loculated pancreatic mass?
# 260 Is/Are the mass located? -yes/no
# 261 Are there gallstones?
# 262 Is/Are there gallstones?
# 263 Are gallstones present?
# 264 Is/Are there gallstones?
# 265 Is the left hemidiaphragm normal?
# 266 Is this image normal?
# 267 Is the left hemidiaphragm normal?
# 268 Is this image normal?
# 269 Is this a chest x-ray?
# 270 Are there abnormal findings on this image?
# 271 Is/Are the brain normal?
# 272 Is this brain scan normal?
# 273 Is/Are the brain normal?
# 274 Is the brain tissue ischemic?
# 275 Is there atrophy of the brain?
# 276 Is the abnormality focal or diffuse?
# 277 Is there evidence of calcification in the mass?
# 278 Is/Are the pancreatic mass calcified? -yes/no
# 279 Is the mass calcified?
# 280 Is/Are the pancreatic mass calcified? -yes/no
# 281 Is this a normal image?
# 282 Is this image normal?
# 283 Is the brain scan normal?
# 284 Is this image normal?
# 285 Is the abnormality hyper dense or hypo dense?
# 286 Is this a lateral film?
# 287 Is there an abnormal lesion?
# 288 Is/Are there a mass?
# 289 Is there a mass?
# 290 Is/Are there a mass?
# 291 Is this a study of the chest?
# 292 Is the hila normal or enlarged?
# 293 Is the liver normal?
# 294 Is/Are the liver normal?
# 295 Is this a normal image?
# 296 Is this image normal?
# 297 Are the lungs normal?
# 298 Is/Are the lung normal?
# 299 Is the chest x-ray normal?
# 300 Is this image normal?
# 301 Is the mass enhancing?
# 302 Is/Are the lung normal?
# 303 Is this image normal?
# 304 Is/Are the lesions ring enhancing ?
# 305 Is there a pelvic fracture?
# 306 Is this a study of the brain?
# 307 Did the patient have a cholecystectomy?
# 308 Is/Are there cholescystectomy
# 309 Has the gallbladder been removed?
# 310 Is/Are there gallbladder removed?
# 311 Is there evidence of enhancement?
# 312 Is/Are the lesion enhanced? -yes/no
# 313 Is the lesion enhancing?
# 314 Is/Are the lesion enhanced? -yes/no
# 315 Is there contrast given?
# 316 Is this a CT scan?
# 317 Are there 2 kidneys?
# 318 Are there two kidneys?
# 319 Are there normal number of kidneys?
# 320 Are there two kidneys?
# 321 Is this image normal?
# 322 Is this image normal?
# 323 Is this image normal?
# 324  Is/Are the right hemidiaphragm normal?
# 325 Is the mass homogeneous?
# 326 Does the mass affect neighboring structure?
# 327 Is/Are there mass effect?
# 328 Is there mass effect?
# 329 Is/Are there mass effect?
# 330 Is this image normal?
# 331 Is the small bowel filled with contrast?
# 332 Is the cecum dilated
# 333 Is there fat stranding?
# 334 Is the heart abnormal?
# 335 Does the heart appear enlarged?
# 336 Is/Are the heart enlarged? -yes/no
# 337 Is/Are the pancreas surrounding normal?
# 338 Is/Are the pancreas surrounding normal?
# 339 Is/Are there a pneumothorax present?
# 340 Do the lung markings extend to the periphery?
# 341 Is a pneumothorax present in this image?
# 342 Does the width of the heart exceed more than half of the thorax?
# 343 How wide is/are the cardiac shadow? -open
# 344 Is the diaphragm obscured?
# 345 Is/Are the diaphragm obscured?
# 346 Is the diaphragm clearly visualized on both sides?
# 347 Is/Are the diaphragm visualized?
# 348 Are nodular calcifications present in the lungs?
# 349 Are the calcifications superior or inferior to the diaphragm?
# 350 Do bones appear lighter on this image's modality?
# 351 Are the bowel loops on the right or left side of the patient?
# 352 Is there evidence of periappendiceal fluid and fat stranding?
# 353 Is the appendix visualized with contrast?
# 354 Is/Are there contrast in the patient's appendix?
# 355 Is there contrast in the appendix?
# 356 Is/Are there contrast in the patient's appendix?
# 357 Is/Are there more than one intussusception present?
# 358 Are any organs besides the intestines present in this image?
# 359 Is a cystic cavity present in the left kidney on this image?
# 360 Is/Are there a cystic cavity in the left kidney?
# 361 Is there a cyst in the left kidney?
# 362 Is/Are there a cyst in the left kidney?
# 363 Is this in the lumbar vertebral level?
# 364 Is the pathologic part of this image the small bowel or colon?
# 365 Is there more that one lesion present?
# 366 Is/Are there more than one lesion present?
# 367 Is the liver normal?
# 368 Is/Are the liver normal?
# 369 Is a ring enhancing lesion present in the right lobe of the liver?
# 370 Is/Are there ring enchancing lesion in the patient's liver?
# 371 Is the lesion on the patient's right or left side?
# 372 Is/Are the diaphragm visualized?
# 373 Is/Are the diaphragm obscured?
# 374 Is the liver abnormal?
# 375 Is/Are the liver abnormal?
# 376 Are there any abnormal hypodense lesions in the liver?
# 377  Is/Are there abnormal hypodense lesions in the patient's liver?
# 378 Is/Are the heart wider than more than half the width of the thorax?
# 379 Is/Are the free air under the left hemidiaphragm  pathologic?
# 380 Is/Are the free air under the left hemidiaphragm  pathologic?
# 381 Is the largest cyst in the left or right kidney?
# 382 Was oral or IV contrast used?
# 383 Are the lesions in the image more or less dense than surrounding tissue?
# 384 Is the primary abnormality more or less dense than surrounding matter?
# 385 What is denser, the mass or the surrounding brain tissue?
# 386 Is the lesion in this image more or less dense than the surrounding tissue?
# 387 What is denser, the lesion or the surrounding tissue?
# 388 Was contrast applied?
# 389 Is this an AP image?
# 390 Are calcified lesions present in the lung fields?
# 391 Is there evidence of large calcified lesions in the lung fields?
# 392 Is/Are there calcified lesions in the patient's lung fields?
# 393 Is/Are there free air in the patient's supraclavicular fossae?
# 394 Is the air under the left hemidiaphragm pathologic?
# 395 Is/Are the air under the left hemidiaphragm pathologic?
# 396 Is there free air under the left diaphragm?
# 397 Is/Are there free air in the patient's subdiaphram?
# 398 Is this image of the thorax?
# 399 Is this image a CT scan?
# 400 Is there evidence of hematoma?
# 401 Is/Are there a hematoma present?
# 402 Is there blood present?
# 403 Is/Are there blood present?
# 404 Is the duodenum edematous?
# 405 Is the largest air collection on the patient's left or the right side?
# 406 Is the air under the left hemidiaphragm pathologic?
# 407 Is/Are the air under the left hemidiaphragm pathologic?
# 408 Is subdiaphragmatic air present on the left side?
# 409 Is/Are there subdiaphragmatic air in the patient's left side?
# 410 Is there an intussusception present?
# 411 Is/Are there an intussusception present?
# 412 Is there evidence of intussusception on the right side?
# 413 Is/Are there an intussusception present?
# 414 Is there a mass in the right hilum?
# 415 Is/Are there a mass in the patient's right hilum?
# 416 Is there evidence of a mass lesion at the right hilum?
# 417 Is/Are there a mass in the patient's right hilum?
# 418 Is there a fracture on the left 5th rib?
# 419 Is/Are there fracture in the patient's 5th rib?
# 420 Is the left fifth rib broken?
# 421 Is/Are there fracture in the patient's 5th rib?
# 422 Is subcutaneous air present?
# 423 Is/Are there subcutaneous air present?
# 424 Is there evidence of subcutaneous air collection?
# 425 Is/Are there subcutaneous air present?
# 426 Are any ribs in the image fractured?
# 427 Is/Are there fracture in the patient's  ribs?
# 428 Are there any fractures present?
# 429 Is/Are there any fractures present?
# 430 Is/Are there subcutaneous air present in the patient's right neck?
# 431 Is the opacity near the left lung apex pathologic?
# 432 Is/Are the opacity near the left lung apex pathologic?
# 433 Is/Are there a pneumonthorax in the patient's left apex?
# 434 Is there any inappropriate air collection in subcutaneous tissue?
# 435 Is/Are there subcutaneous air present?
# 436 Is subcutaneous air present?
# 437 Is/Are there subcutaneous air present?
# 438 Is the costophrenic angle blunted?
# 439 Is/Are the costophrenic angle blunted? -yes/no
# 440 Is there any hemorrhage?
# 441 Is the cerebellum visible?
# 442 Is this an axial image?
# 443 Is the liver normal in size?
# 444 Is this film properly exposed?
# 445 Is it possible to see the cerebellum in this image?
# 446 Is the heart dilated?
# 447 Is the patient's kidney this large mass to the right?
# 448 Are these small opacities in the right lung calcifications?
# 449 Is there any shifting on the path of the trachea?
# 450 Is there swelling of the choroid fissure?
# 451 Is this a MRI image?
# 452 Is there swelling around the lesion?
# 453 Are the basal ganglia enlarged?
# 454 Is there any other alteration in the image?
# 455 Is the medulla swollen?
# 456 Is the lesion infiltrating?
# 457 Is the abdomen distended?
# 458 Is there leakage of contrast?
# 459 Is this a solitary nodule?
# 460 Is there ascites?
# 461 Is there any hemorrhage?
# 462 Is the right lung normal in size?
# 463 Is there a cyst in the right kidney?
# 464 Is there involvement of the temporal lobes?
# 465 Are the brain ventricles visible?
# 466 Is there fluid in the anterior abdominal wall?
# 467 Are the lateral ventricles compressed?
# 468 Is this a cyst in the left lung?
# 469 Is the stomach dilated?
# 470 Is the right kidney at its normal height in the abdomen?
# 471 Is this an infiltrating mass?
# 472 Is it contrast these hyperintensities in the intestines?
# 473 Is there lesion to other structures besides the medulla?
# 474 Are there any other cysts in the image?
# 475 Is there any lesion in the left kidney
# 476 Are there multiple masses or just a single big one?
# 477 Are the kidneys atrophied?
# 478 Is it possible to see the cerebellum?
# 479 Is this a CT image?
# 480 Is the left kidney affected?
# 481 Is the brain atrophied or shrunk?
# 482 Are there fractures on the skull?
# 483 Is there any lesion to bone structures?
# 484 Is the heart a normal size?
# 485 Is/Are the heart size normal?
# 486 Is the heart size normal?
# 487 Is/Are the heart size normal?
# 488 Can a pulmonary mass be appreciated?
# 489 Is a pulmonary mass present?
# 490 Is this a solid or cystic lesion?
# 491 Is the lesion a solid or cystic lesion?
# 492 Is this in the PA plane?
# 493 Is there anything abnormal about the heart size?
# 494 Is the heart enlarged?
# 495 Is/Are the heart enlarged?
# 496 Is/Are there an esophagus present?
# 497 Is/Are there an esophagus present?
# 498 Is this patient male or female?
# 499 Is the cerebellum present in the image?
# 500 Can this image highlight bone fractures (if present)?
# 501 Can you appreciate a pleural effusion?
# 502 Is/Are there a pleural effusion?
# 503 Is a pleural effusion present?
# 504 Is/Are there a pleural effusion?
# 505 Do you see a subdural hematoma?
# 506 Is/Are there a subdural hematoma?
# 507 Is there a subdural hematoma?
# 508 Is/Are there a subdural hematoma?
# 509 Is the heart enlarged?
# 510 Is/Are the heart enlarged?
# 511 Is the heart size increased?
# 512 Is/Are the heart enlarged?
# 513 Is this a ring enhancing lesion?
# 514 Is/Are there ring-enhancement?
# 515 Is there ring-enhancement?
# 516 Is/Are there ring-enhancement?
# 517 Are the dark areas grey or white matter?
# 518 Is there a fracture?
# 519 Is/Are there a fracture?
# 520 Is a fracture present?
# 521 Is/Are there a fracture?
# 522 Is this image sufficient for a diagnosis?
# 523 Is the image enough to diagnose?
# 524 Is this an abscess or cancer?
# 525 Is there a right-sided pleural effusion?
# 526 Is/Are there a pleural effusion?
# 527 Is there an effusion present on the right-side?
# 528 Is/Are there a pleural effusion?
# 529 Do you see a pleural effusion?
# 530 Is/Are there a Pleural effusion?
# 531 Is a pleural effusion present?
# 532 Is/Are there a Pleural effusion?
# 533 Are sections of bowel recognizable?
# 534 Is a pleural effusion present?
# 535 Is/Are there a pleural effusion?
# 536 Is there a pleural effusion?
# 537 Is/Are there a pleural effusion?
# 538 Is the heart size abnormal?
# 539 Is/Are the heart size abnormal?
# 540 Is the heart enlarged?
# 541 Is/Are the heart enlarged?
# 542 Is the patient lying down?
# 543 Can you evaluate the kidneys 	bladde r	or ureters in this image?
# 544 Is/Are the kidneys normal?
# 545 Is/Are the kidneys normal?
# 546 Is/Are there lateral ventricles?
# 547 Is/Are there lateral ventricles?
# 548 Can you appreciate a shift of the midline?
# 549 Is/Are there a midline shift?
# 550 Is there a midline shift?
# 551 Is/Are there a midline shift?
# 552 Can you diagnose a pericardial effusion from this image?
# 553 Is this image sufficient to diagnose pericardial effusion?
# 554 Can a diagnosis or impression be made in this plane?
# 555 Would perform this same modality in a patient with AKI?
# 556 Are abdominal fat pads prominently visualized?
# 557 Is/Are there abdominal fat pads visible?
# 558 Can you see the abdominal fat pads?
# 559 Is/Are there abdominal fat pads visible?
# 560 Is there a pleural effusion present?
# 561 Is/Are there pleural effusion?
# 562 Is there a pleural effusion
# 563 Is/Are there pleural effusion?
# 564 Did this patient sustain physical damage?
# 565 Do you suspect a physical injury?
# 566 Can you see all of the ribs on the left side?
# 567 Can the left ribs be evaluated?
# 568 Can you appreciate a pleural effusion anywhere?
# 569 Is pleural effusion present?
# 570 Are adrenal glands present in this image?
# 571 Can you see the adrenals?
# 572 Did the problem originate in the brain?
# 573 Do you suspect a primary brain process?
# 574 Is/Are there a fracture in the patient's vertebrae?
# 575 Is/Are there a fracture in the patient's vertebrae?
# 576 Does the left humerus appear to be fractured?
# 577 Is/Are the humerus fractured?
# 578 Is there a fracture of the left humerus?
# 579 Can this plane detect an aortic aneurysm 	if present?
# 580 Can a diagnosis of appendicitis be made from this image?
# 581 Is this confirmed appendicitis?
# 582 Are both lungs abnormally inflated?
# 583 Can you visualize the 4th ventricle?
# 584 Is/Are there 4th ventricle present?
# 585 Is the 4th ventricle present in this image?
# 586 Is/Are there 4th ventricle present?
# 587 Can a pleural effusion be appreciated on the right side?
# 588 Is/Are there a right pleural effusion?
# 589 Is there a right-sided pleural effusion?
# 590 Is/Are there a right pleural effusion?
# 591 Do you suspect a physical injury or a medical process?
# 592 What is the cause of this finding: medical process or physical injury?
# 593 Does the skull appear fractured?
# 594 Is there a skull fracture?
# 595 Is this an anoxic injury?
# 596 Is there anoxic brain infarction?
# 597 Is/Are there hylar lymphadenopathy?
# 598 Is/Are there hylar lymphadenopathy?
# 599 Is/Are there a widened mediastinum?
# 600 Is/Are there a widened mediastinum?
# 601 Does this image show heart failure?
# 602 is this heart failure
# 603 Is/Are the heart enlarged?
# 604 Is/Are the heart enlarged?
# 605 is the heart enlarged?
# 606 Is/Are the heart enlarged?
# 607 Is there cardiomegaly?
# 608 Is/Are the heart enlarged?
# 609 Is this coronal plane?
# 610 is the stomach wall thickened?
# 611 Is/Are there thickening in the patient's gastric wall?
# 612 Is there thickening of the gastric wall?
# 613 Is/Are there thickening in the patient's gastric wall?
# 614 is this an axial plane image
# 615 Is/Are there a pleural effusion?
# 616 Is/Are there a pleural effusion?
# 617 Is/Are there mass effect?
# 618 Is/Are there mass effect?
# 619 Is there a lung mass?
# 620 Is/Are there a lung mass?
# 621 Is there a mass in the lung?
# 622 Is/Are there a lung mass?
# 623 is there a bowel obstrution
# 624 Is/Are there obstruction in the patient's bowel?
# 625 Is the bowel obstructed?
# 626 Is/Are there obstruction in the patient's bowel?
# 627 Is there hemorrhage?
# 628 Is/Are there hemorrhage?
# 629 Is hemorrhage seen?
# 630 Is/Are there hemorrhage?
# 631 is the peritoneum thickened?
# 632 Is/Are there thickening in the patient's peritoneum?
# 633 Is there thickening of the peritoneum?
# 634 Is/Are there thickening in the patient's peritoneum?
# 635 Is this mass located in the liver?
# 636 Is/Are the mass located near/in the liver?
# 637 Is this a hepatic mass?
# 638 Is/Are the mass located near/in the liver?
# 639 Is/Are there a mass?
# 640 Is/Are there a mass?
# 641 does this constitute a pulmonary pathology?
# 642 Are the sulci blunted?
# 643 Is/Are there blunted sulci?
# 644 Is there blunting of the sulci?
# 645 Is/Are there blunted sulci?
# 646 is the mass cystic?
# 647 Is/Are the mass cystic? -yes/no
# 648 Would you describe the mass as cystic?
# 649 Is/Are the mass cystic? -yes/no
# 650 Is this lesion loculated
# 651 Is/Are the lesion loculated? -yes/no
# 652 Is there loculation of this lesion?
# 653 Is/Are the lesion loculated? -yes/no
# 654 Is this a standing CXR
# 655 is this an AP CXR
# 656 Is this an axial image?
# 657 Is/Are there edema in the patient's brain?
# 658 Is/Are there edema in the patient's brain?
# 659 is the pulmonary system shown?
# 660 Is the structure cystic?
# 661 Is/Are the mass cystic?
# 662 Is the mass a cyst?
# 663 Is/Are the mass cystic?
# 664 Do the masses contain calcification?
# 665 Is/Are there calcification?
# 666 is there calcification
# 667 Is/Are there calcification?
# 668 Is the mediastinum widened?
# 669 Is/Are there a widened mediastinum?
# 670 Is there a widened mediastium?
# 671 Is/Are there a widened mediastinum?
# 672 is the stomach filled?
# 673 Is/Are there fullness in the patient's stomach?
# 674 Is there gastric fullness?
# 675 Is/Are there fullness in the patient's stomach?
# 676 is the renal system dilated?
# 677 Is/Are the kidney dilated?
# 678 Is there hydronephrosis?
# 679 Is/Are the kidney dilated?
# 680 Is/Are there increased vascular markings?
# 681 Is/Are the vascular markings increased?
# 682 Is the bowel dilated?
# 683 Is/Are there dilation in the patient's bowel?
# 684 is there dilation of the bowel?
# 685 Is/Are there dilation in the patient's bowel?
# 686 Can you appreciate a mass in this image?
# 687 Is/Are there a mass?
# 688 is there a mass demonstrated?
# 689 Is/Are there a mass?
# 690 Doe this image depict an interstitial lung process?
# 691 Is/Are there interstitial process in the patient's lungs?
# 692 Is there an interstitial lung process?
# 693 Is/Are there interstitial process in the patient's lungs?
# 694 is the caudate nucleus involved?
# 695 Is the caudate nucleus involved?
# 696 Is there involvement of the caudate nucleus?
# 697 Is/Are the pathology located near/in the caudate nucleus?
# 698 Is this a PA film?
# 699 Does the pathology involve the CV system
# 700 Does this image show a normal gallbladder?
# 701 Is/Are the gallbladder normal?
# 702 Is the GB normal?
# 703 Is/Are the gallbladder normal?
# 704 Is there gall bladder pathology?
# 705 Is the gallbladder abnormal?
# 706 Is there pathology of the gallbladder?
# 707 Is the gallbladder abnormal?
# 708 Can you appreciate inflammation?
# 709 Is/Are there inflammation?
# 710 is there inflammation?
# 711 Is/Are there inflammation?
# 712 Is the chest xray underexposed?
# 713 Is this image underexposed?
# 714 Can you appreciate hemorrhage in this image?
# 715 Is/Are there hemorrhage?
# 716 Is there hemorrhage
# 717 Is/Are there hemorrhage?
# 718 Do you see a cavitary lesion in this chest xray?
# 719 Is/Are there a cavitary lesion?
# 720 is there a cavitary lesion?
# 721 Is/Are there a cavitary lesion?
# 722 Does this patient have cardiomegaly?
# 723 Is this patient intubated?
# 724 Is there intraperitoneal hemorrhage present in this image?
# 725 Can the kidneys be visualized in this CT scan?
# 726 Is this a PA image?
# 727 Does this patient have a pneumothorax?
# 728 Does this radiograph contain parts of the cardiovascular system?
# 729 Does this patient have a skull fracture?
# 730 Does this image show a normal gallbladder?
# 731 Is there fat stranding around the appendix?
# 732 Is the heart enlarged?
# 733 Is there acute blood present on this head CT?
# 734 Does this patient have a pleural effusion?
# 735 Was this image taken in the AP or PA plane?
# 736 Does this xray show an intubated patient?
# 737 Is this an axial image?
# 738 Does this image display the CNS?
# 739 Is this CT scan enhanced by IV contrast?
# 740 Does this image show a pneumothorax?
# 741 Does this image display hydrocephalus?
# 742 Is this a CT scan?
# 743 Is this xray suggestive of aortic dissection?
# 744 Does this patient have any fractured ribs?
# 745 Is there fat stranding shown in this image?
# 746 Is this a contrast enhanced image?
# 747 Is this an MRI?
# 748 Is the width of the abdominal aorta within normal limits?
# 749 Is this image enhanced by contrast?
# 750 Does the appendix appear normal?
# 751 Was this a contrast CT or a non-contrast CT?
# 752 Do we see diffuse cerebral edema in this MRI?
# 753 Is there a clavicle fracture shown in this radiograph?
# 754 Is this a contrast CT or a non-contrast CT?
# 755 Does this patient have an endotracheal tube placed?
# 756 Does this CXR display pneumoperitoneum?
# 757 Is the appendix seen in this image ruptured?
# 758 Can the liver be seen in this image?
# 759 Can you see intraperitoneal bleeding in this CT?
# 760 Is the appendix seen in this image inflamed?
# 761 Does this image display the contents of the abdomen?
# 762 Was contrast used with this image?
# 763 Does this image show a pleural effusion?
# 764 Is the Saggital plane?
# 765 Is there evidence of pneumothorax?
# 766 Is/Are there pneumothorax?
# 767 Is there a pneumothorax?
# 768 Is/Are there pneumothorax?
# 769 Are the pulmonary arteries enlarged?
# 770 Is/Are the pulmonary arteries enlarged?
# 771 Do the pulmonary arteries appear enlarged?
# 772 Is/Are the pulmonary arteries enlarged?
# 773 Is this an mri?
# 774 Is/Are the lesion wedge-shaped? -yes/no
# 775 Is/Are the lesion wedge-shaped? -yes/no
# 776 Are the lesions in the cerebellum?
# 777 Are the findings normal?
# 778 Is this image normal?
# 779 Is this a normal image?
# 780 Is this image normal?
# 781 Is this normal gallbladder finding?
# 782 Does the lesion demonstrate ring enhancement?
# 783 Is/Are the lesion ring enhancing? -yes/no
# 784 Is this lesion ring enhancing?
# 785 Is/Are the lesion ring enhancing? -yes/no
# 786 Is there evidence of calcification?
# 787 Is/Are the mass calcified? -yes/no
# 788 Is the mass calcified?
# 789 Is/Are the mass calcified? -yes/no
# 790 Do you always recommend using both IV and oral contrast?
# 791 Are the lungs hyperinflated?
# 792 Is/Are the lungs hyperinflated?
# 793 Do the lungs appear hyperinflated?
# 794 Is/Are the lungs hyperinflated?
# 795 Do you see dependent layering in the occipital horns of the lateral ventricles?
# 796 Is/Are there dependent layering in the occipital horns of the lateral ventricles??
# 797 Is there dependent layering in the occipital horns of the lateral ventricles?
# 798 Is/Are there dependent layering in the occipital horns of the lateral ventricles??
# 799 Are the enhanced muscles also enlarged?
# 800 Is/Are the enhanced muscles enlarged? -yes/no
# 801 Do the enhanced muscles appear enlarged?
# 802 Is/Are the enhanced muscles enlarged? -yes/no
# 803 Is/Are there an acute infarction in the patient's brain?
# 804 Is/Are there an acute infarction in the patient's brain?
# 805 Is/Are the trachea located near/in the midline?
# 806 Is the trachea midline?
# 807 Is the lesion located in gray or white matter?
# 808 Where is the lesion located?
# 809 Is the lesion seen in the gray or white matter?
# 810 Where is the lesion located?
# 811 Are the findings normal?
# 812 Is this image normal?
# 813 Is this image normal?
# 814 Is this image normal?
# 815 Is this image best taken on expiration?
# 816 Does the R vertebral artery appear normal?
# 817 Is/Are the R vertebral artery normal?
# 818 Is the Right vertebral artery normal?
# 819 Is/Are the R vertebral artery normal?
# 820 Do you see fluid in the left lung?
# 821 Is/Are there fluid in the patient's left lung?
# 822 Is there fluid in the left lung?
# 823 Is/Are there fluid in the patient's left lung?
# 824 Does the heart appear normal size?
# 825 Is/Are the heart normal size?
# 826 Is the width of the cardiac silhouette normal?
# 827 Is/Are the heart normal size?
# 828 Any evidence of epidural or subdural hematoma?
# 829 Is/Are there epidural or subdural hematoma?
# 830 Are there epidural or subdural bleeds as well?
# 831 Is/Are there epidural or subdural hematoma?
# 832 Is there evidence of hemorrhage?
# 833 Is there a hemorrhagic mass?
# 834 Is the mass hemorrhagic?
# 835 Is there a hemorrhagic mass?
# 836 Is the image above oriented in the axial plane?
# 837 Are there any bone fractures present?
# 838 Is/Are there bone fractures?
# 839 Does the patient have any bone fractures?
# 840 Is/Are there bone fractures?
# 841 Are the patients' ribs symmetric on both sides?
# 842 Is/Are there symmtery in the patient's ribs on both sides?
# 843 Is there symmetry of the patient's ribs on both sides?
# 844 Is/Are there symmtery in the patient's ribs on both sides?
# 845 Is the heart enlarged?
# 846 Is the heart enlarged?
# 847 Does this image show edema?
# 848 Is/Are there edema ?
# 849 Is there edema?
# 850 Is/Are there edema ?
# 851 Is this taken in the axial plane?
# 852 Are the colon walls thickened?
# 853 Is there colon thickening?
# 854 Are the walls of the colon thickened?
# 855 Is there colon thickening?
# 856 Is the image an CT scan?
# 857 Was this image taken with or without contrast?
# 858 Was contrast used to take this image?
# 859 Did the patient ingest contrast prior to taking this image?
# 860 Was contrast used in this image?
# 861 Is/Are there there hemorrhage  in the patient's kidneys ?
# 862 Is/Are there there hemorrhage  in the patient's kidneys ?
# 863 Does the lesion above enhance?
# 864 Is the lesion enchanced?
# 865 Is there enhancement of the lesion?
# 866 Is the lesion enchanced?
# 867 Is the consistency of the abscess located in the left upper quadrant homogeneous or heterogeneous?
# 868 How would you describe the consistency of the abscess as homogenous or heterogenous?
# 869 Is the abscess in the left upper quadrant homogenous or heterogenous?
# 870 How would you describe the consistency of the abscess as homogenous or heterogenous?
# 871 Is there a pneumothorax seen in the above image?
# 872 Is/Are there a pneumothorax?
# 873 Is there a pneumothorax present?
# 874 Is/Are there a pneumothorax?
# 875 Is this a noncontrast CT?
# 876 Does the image show midline shift?
# 877 Is/Are there midline shift present?
# 878 Is there midline shift?
# 879 Is/Are there midline shift present?
# 880 Does the heart look enlarged?
# 881 Is/Are the heart enlarged ?
# 882 Is the heart enlarged?
# 883 Is/Are the heart enlarged ?
# 884 Is the heart larger than normal?
# 885 Is/Are the the heart enlarged?
# 886 Is the heart enlarged?
# 887 Is/Are the the heart enlarged?
# 888 Does this image show midline shift?
# 889 Is there midline shift?
# 890 Is there midline shift in this image?
# 891 Is there midline shift?
# 892 Is there mass shift pathology?
# 893 Is/Are there mass shift?
# 894 Is there any mass shift?
# 895 Is/Are there mass shift?
# 896 Is the heart enlarged?
# 897 Is the heart enlarged?
# 898 Is this a PA film?
# 899 Are there multiple lesions in the chest of the above patient?
# 900 Is there multiple lesions in the patient's chest?
# 901 Does this patient have multiple lesions in their chest?
# 902 Is there multiple lesions in the patient's chest?
# 903 Does the image show pericolonic fat stranding?
# 904 Is/Are there fat stranding  in the patient's pericolonic region?
# 905 Is there pericolic fat stranding?
# 906 Is/Are there fat stranding  in the patient's pericolonic region?
# 907 Is this an image of the brain?
# 908 Is this MRI with contrast or without contrast?
# 909 Was this MRI taken with or without contrast?
# 910 Are the pulmonary nodules diffuse in the chest or lateralized to one side?
# 911 Where are the pulmonary nodules located?
# 912 Is the location of the pulmonary nodules diffuse or lateralized to one side?
# 913 Where are the pulmonary nodules located?
# 914 Are the lesions only in one lobe?
# 915 Is/Are the lesions located near/in the one lobe?
# 916 Are the opacities confined to one lung lobe?
# 917 Is/Are the lesions located near/in the one lobe?
# 918 Is the lesion in the image enhancing?
# 919 Is/Are the lesion enhancing? -yes/no
# 920 Is the mass contrast-enhancing?
# 921 Is/Are the lesion enhancing? -yes/no
# 922 Is the cortex atrophied?
# 923 Is/Are the cortex atrophied?
# 924 Is there cortical atrophy?
# 925 Is/Are the cortex atrophied?
# 926 Is/Are there free air?
# 927 Is/Are there free air?
# 928 Are these masses encompassing the aorta?
# 929 Is/Are the masses located near/in the aorta?
# 930 Are the liver masses growing around the aorta?
# 931 Is/Are the masses located near/in the aorta?
# 932 Are the ventricles enlarged?
# 933 Are the ventricles enlarged?
# 934 Is this a mid-sagittal film?
# 935 Is there free air under the diaphragm?
# 936 Is/Are there air in the abdomen?
# 937 Is there air in the abdominal cavity?
# 938 Is/Are there air in the abdomen?
# 939 Is this an axial image?
# 940 Is a skull fracture present?
# 941 Is/Are the skull fractured? -yes/no
# 942 Is the skull fractured?
# 943 Is/Are the skull fractured? -yes/no
# 944 What is/are the hypodense mass near/in the liver?
# 945 Is there free air under the diaphragm?
# 946 Is/Are there free air in the patient's (under the) diaphragm?
# 947 Is subdiaphragmatic free air present?
# 948 Is/Are there free air in the patient's (under the) diaphragm?
# 949 Are there any consolidations present in the lungs?
# 950 Is/Are there pulmonary consolidations?
# 951 Are there any pulmonary consolidations?
# 952 Is/Are there pulmonary consolidations?
# 953 Is the vertebrae fractured?
# 954 Is/Are there vertebral fracture?
# 955 Is there a vertebral fracture?
# 956 Is/Are there vertebral fracture?
# 957 Is the heart shadow abnormally large?
# 958 Is/Are the heart shadow abnormally large?
# 959 Is the cardiac silhouette enlarged?
# 960 Is/Are the heart shadow abnormally large?
# 961 Is there a pneumothorax?
# 962 Is/Are there pneumothorax?
# 963 Is a pneumothorax present?
# 964 Is/Are there pneumothorax?
# 965 Is/Are the trachea normal?
# 966 Is/Are the trachea normal?
# 967 Is there pneumothorax?
# 968 Is the pelvis of the left kidney dilated?
# 969 Is/Are the left renal pelvis dilated?
# 970 Is the left renal pelvis dilated?
# 971 Is/Are the left renal pelvis dilated?
# 972 Is the bowel perforated?
# 973 Is/Are there bowel perforation?
# 974 Is there bowel perforation present?
# 975 Is/Are there bowel perforation?
# 976 Can the white and gray matter be differentiated?
# 977 Is there good gray-white matter differentiation?
# 978 What is/are the free air near/in the thorax?
# 979 What is/are the free air near/in the thorax?
# 980 Are there cilia present at the level of alveoli?
# 981 Are any of the ribs fractured?
# 982 Is/Are the ribs fractured? -yes/no
# 983 Are there rib fractures present?
# 984 Is/Are the ribs fractured? -yes/no
# 985 Does a blocked alveoli cause a V/Q mismatch?
# 986 Are the ventricles enlarged?
# 987 Is/Are the ventricles enlarged?
# 988 Is there ventricular enlargement?
# 989 Is/Are the ventricles enlarged?
# 990 Is/Are there enhancing lesion in the patient's liver?
# 991 Is/Are there enhancing lesion in the patient's liver?
# 992 Is the mass surrounding the aorta?
# 993 Is/Are the mass located near/in the (surrounding the) aorta?
# 994 Is the aorta encompassed by the mass?
# 995 Is/Are the mass located near/in the (surrounding the) aorta?
# 996 Is the trachea deviated from midline?
# 997 Is/Are there tracheal deviation?
# 998 Is there tracheal deviation?
# 999 Is/Are there tracheal deviation?
# 1000 Can x rays be used to identify liver lesions?
# 1001 Is the pancreatic mass enhancing?
# 1002 Is/Are the pancreatic mass enhancing?
# 1003 Is the mass in the pancreas enhancing?
# 1004 Is/Are the pancreatic mass enhancing?
# 1005 Can CT be used to assess soft tissues?
# 1006 Are the hemidiaphragms flattened?
# 1007 Is/Are the diaphragm  flattened? -yes/no
# 1008 Is the diaphragm flattened on either side
# 1009 Is/Are the diaphragm  flattened? -yes/no
# 1010 Is the bowel perforated?
# 1011 Is/Are there a perforated bowel?
# 1012 Is there sign of perforated bowel?
# 1013 Is/Are there sign of perforated bowel?
# 1014 Are any fractures present?
# 1015 Is/Are there fractures?
# 1016 Is there a skull fracture?
# 1017 Is/Are there fractures?
# 1018 Is there a skull fracture present?
# 1019 Is/Are the skull fractured? -yes/no
# 1020 Is the skull fractured?
# 1021 Is/Are the skull fractured? -yes/no
# 1022 Is/Are there skeletal joints?
# 1023 Is the cardiac silhouette enlarged?
# 1024 Is/Are the heart size abnormal?
# 1025 Is the heart size abnormal
# 1026 Is/Are the heart size abnormal?
# 1027 Is there a subarachnoid bleed in the image?
# 1028 Is/Are there subarachnoid bleeding?
# 1029 Is a subarachnoid bleed present?
# 1030 Is/Are there subarachnoid bleeding?
# 1031 Does the right kidney show signs of hydronephrosis?
# 1032 Is/Are the right kidney abnormal?
# 1033 Is the right kidney abnormal here?
# 1034 Is/Are the right kidney abnormal?
# 1035 Is the lesions located on the left or right?
# 1036 Is the aorta abnormally wide?
# 1037 is the aortic knob widened?
# 1038 Is the aortic knob widened?
# 1039 is the aortic knob widened?
# 1040 Is the trachea normal?
# 1041 Is/Are the trachea normal?
# 1042 Is the trachea midline?
# 1043 Is the trachea midline?
# 1044 Are there skull fractures?
# 1045 Is there a skull fracture?
# 1046 Is/Are there sign of skull fracture?
# 1047 Is/Are there sign of skull fracture?
# 1048 Are the cortexes atrophied here?
# 1049 Is the cortex atrophied?
# 1050 Is cortical atrophy present?
# 1051 Is the cortex atrophied?
# 1052 Is there a pneumothorax?
# 1053 Is/Are there pneumothorax?
# 1054 Is a pneuomothorax present?
# 1055 Is/Are there pneumothorax?
# 1056 Is the skull fractured?
# 1057 Is/Are the skull fractured? -yes/no
# 1058 Is there a skull fracture?
# 1059 Is/Are the skull fractured? -yes/no
# 1060 Is/Are there pneumothorax?
# 1061 Is/Are there pneumothorax?
# 1062 Are the clavicles fractured?
# 1063 Is/Are there clavicular fracture?
# 1064 Is a clavicular fracture present?
# 1065 Is/Are there clavicular fracture?
# 1066 Is the liver lacerated?
# 1067 Is/Are the damage located near/in the liver?
# 1068 Is there damage to the liver?
# 1069 Is/Are the damage located near/in the liver?
# 1070 Is a pleural effusion present?
# 1071 Is/Are there pleural effusion?
# 1072 Is there a pleural effusion?
# 1073 Is/Are there pleural effusion?
# 1074 Is/Are the diaphragm flat? -yes/no
# 1075 Is/Are the diaphragm flat? -yes/no
# 1076 Is this in the coronal plane?
# 1077 Is there lymphadenopathy?
# 1078 Is there lymphadenopathy?
# 1079 Is lymphadenopathy present?
# 1080 Is there lymphadenopathy?
# 1081 Are the ventricles unaltered?
# 1082 Is/Are the ventricles normal?
# 1083 Are the ventricles normal?
# 1084 Is/Are the ventricles normal?
# 1085 Is this image abnormal?
# 1086 Is/Are there lesions?
# 1087 Is the mass heterogenous?
# 1088 Is/Are the mass heterogeneous?
# 1089 Is the mass varied?
# 1090 Is/Are the mass heterogeneous?
# 1091 Is there mass effect seen on this image?
# 1092 Is there mass effect?
# 1093 Is there bulging of structures in this image?
# 1094 Is/Are the affected areas enlarged?
# 1095 Is there edema present near the lesion?
# 1096 Is/Are there fluid accumulation in the patient's brain?
# 1097 Is there fluid accumulation near the lesion?
# 1098 Is/Are there fluid accumulation in the patient's brain?
# 1099 Are there abnormal findings?
# 1100 Is this image abnormal?
# 1101 Is anything irregular in this image?
# 1102 Is this image abnormal?
# 1103 Is this an image of normal physiology?
# 1104 Is this patient healthy?
# 1105 Is/Are there a focal mass?
# 1106 Is/Are there a focal mass?
# ...
# 1444 Is there evidence of grey matter edema?
# 1445 Is there fat in these masses?
# 1446 Is/Are there fat in the patient's masses?
# 1447 Is there a fracture of the clavicle?
# 1448 Is/Are there a fracture in the patient's clavicle?
# 1449 Is there mass effect from the lesion?
# 1450 Is/Are the lesion causing mass effect? -yes/no
# 1451 Are the kidneys in this image abnormal?
# 1452 Is/Are the kidneys normal?
# 1453 Is the mass enhancing?
# 1454 Is/Are the mass enhancing?
# 1455 Is there a shift of midline structures?
# 1456 Does the patient have a central line placed?
# 1457 Is/Are there central line in the patient's heart?
# 1458 Does the L sided lesion enhance?
# 1459 Is/Are the L sided lesion enhancing? -yes/no
# 1460 Are the findings normal?
# 1461 Is this image normal?
# 1462 Is the heart too big?
# 1463 Is/Are the heart too big?
# 1464 Do the ventricles have blood in them?
# 1465 Is/Are there blood in the patient's ventricles?
# 1466 Is this image normal?
# 1467 Are the cystic and common bile ducts dilated?
# 1468 Is/Are the cystic and common bile duct  dilated?
# 1469 Is the cerebellum in view?
# 1470 Is/Are there cerebellum?
# 1471 Is there contrast used in the above image?
# 1472 Is/Are there cortical atrophy?
# 1473 Is there cardiomegaly?
# 1474 Is/Are there cardiomegaly?
# 1475 Is/Are the lesions ring enhancing?
# 1476 Anything abnormal in this image?
# 1477 Is this image abnormal?
# 1478 Is the gall bladder enlarged?
# 1479 Is there contrast used?
# 1480 Is there restricted diffusion?
# 1481 Is/Are there restricted diffusion?
# 1482 Is there mass effect?
# 1483 Is/Are there mass effect?
# 1484 Is/Are there curly B lines?
# 1485 Is a pneumothorax present?
# 1486 Is/Are there a pneumothorax?
# 1487 Where is/are the gastric bubble located?
# 1488 Does this scan represent an abnormality?
# 1489 Is/Are there abnormality?
# 1490 Is the heart clearly visible?
# 1491 Is/Are there an obvious heart outline?
# 1492 Are calcifications present?
# 1493 Is/Are there calcifications ?
# 1494 Is/Are the ribs broken?
# 1495 Was contrast used?
# 1496 Are the findings normal?
# 1497 Is this image normal?
# 1498 Are there rib fractures present?
# 1499 Is/Are there rib fractures?
# 1500 Is the trachea midline?
# 1501 Did this patient receive IV contrast?
# 1502 Was IV contrast given to the patient?
# 1503 Is the CSF radiolucent or radioopaque?
# 1504 Are the ventricles larger than normal?
# 1505 Are the ventricles large?
# 1506 Is there enlargement of the ventricles
# 1507 Are the ventricles enlarged?
# 1508 Are there multiple circumferential opacities located throughout all lung fields?
# 1509 Does this chest x-ray show signs of diffuse opacities in both right and left lung fields?
# 1510 Was this image taken via MRI?
# 1511 Is this image taken from the top slice of the brain?
# 1512 Was this image taken from a superior-most section of the brain?
# 1513 Was this image taken with an MRI or CT scanner?
# 1514 Can you view the colon in this image?
# 1515 Is the transverse colon in view?
# 1516 Is the CSF enhanced or non enhanced?
# 1517 Are the air fluid levels located in colon?
# 1518 Is this an AP or PA film?
# 1519 Is the appendix non-enlarged?
# 1520 Is the appendix normal size?
# 1521 Is this patient rotated?
# 1522 Was the patient positioned inappropriately?
# 1523 Is this a T1 weighted, T2 weighted, or FLAIR image?
# 1524 Is this MRI taken with FLAIR protocol?
# 1525 Is this image of a saggital plane?
# 1526 Is there right hemidiaphragm elevation?
# 1527 Is/Are there elevation of the right hemidiaphragm?
# 1528 Is the right hemidiaphragm higher than the left?
# 1529 Is/Are there elevation of the right hemidiaphragm?
# 1530 Is the jejunal wall enlarged?
# 1531 Is the jejunal wall enlarged?
# 1532 Is there thickening of the jejunum
# 1533 Is the jejunum thickened?
# 1534 Is the heart contour backwards?
# 1535 Is the heart contour a mirror image of normal?
# 1536 Does the left temporal lobe appear normal?
# 1537 Is the left temporal lobe normal?
# 1538 Is there a lesion in the left temporal lobe?
# 1539 Is there a lesion located in the left temporal lobe?
# 1540 Is this a saggital brain section?
# 1541 Is this a saggital view of the brain?
# 1542 Is there a hypodensity located in the liver?
# 1543 Is there a hypodensity located in the liver?
# 1544 Is the aorta visible in this section?
# 1545 Is there an aorta in the image?
# 1546 Is the aorta in view?
# 1547 Is there an aorta in the image?
# 1548 Are the kidneys hyper attenuated?
# 1549 Is/Are the kidneys showing high level of contrast?
# 1550 Do the kidneys show a high level of contrast enhancement?
# 1551 Is/Are the kidneys showing high level of contrast?
# 1552 Are both kidneys in view?
# 1553 Are both kidneys in the image?
# 1554 Are both kidneys visible?
# 1555 Are both kidneys in the image?
# 1556 Does the appendix appear normal or abnormal?
# 1557 Is there appendix normal or abnormal in appearance?
# 1558 Is this a chest radiograph?
# 1559 Does the heart border appear normal?
# 1560 Is the heart contour normal?
# 1561 Is there a normal contour of the heart?
# 1562 Is the heart contour normal?
# 1563 Is this an AP or PA film?
# 1564 Is the heart enlarged?
# 1565 Is the heart enlarged?
# 1566 Is there evidence of cardiomegaly?
# 1567 Is the heart enlarged?
# 1568 Is this an AP or PA film?
# 1569 Are the ground glass opacities located more in the apex or base of the lung?
# 1570 Is there oral contrast located in the colon?
# 1571 Is there oral contrast located in the colon?
# 1572 Is there oral contrast in the colon?
# 1573 Is there oral contrast located in the colon?
# 1574 Did this patient receive IV contrast?
# 1575 Was IV contrast given to the patient?
# 1576 Does the CSF have high signal intensity?
# 1577 Is the CSF high signal intensity?
# 1578 Is there high signal intensity in the CSF?
# 1579 Is the CSF high signal intensity?
# 1580 Is this a T1 weighted, T2 weighted, or FLAIR image?
# 1581 Does this image use GI contrast?
# 1582 Is this a contrast enhanced image?
# 1583 Is there cardiomegaly?
# 1584 Is the heart enlarged?
# 1585 Is the heart enlarged?
# 1586 Is the heart enlarged?
# 1587 Is this a cystic or solid mass?
# 1588 Does this CT use IV contrast material?
# 1589 Is this a contrast or non contrast CT?
# 1590 Are the lungs hyperinflated?
# 1591 Is the left hemodiaphragm flat?
# 1592 Is the left hemodiaphragm flat?
# 1593 Is this a PA film?
# 1594 Is there any costophrenic angle blunting present?
# 1595 Is there any costophrenic angle blunting?
# 1596 Is there presence of any costophrenic angle blunting?
# 1597 Is there any costophrenic angle blunting?
# 1598 Do you see a pleural effusion?
# 1599 Is there a pleural effusion?
# 1600 Is there a pleural effusion present?
# 1601 Is there a pleural effusion?
# 1602 Are the ventricles visualized in this image?
# 1603 Are you able to see the ventricles in this image?
# 1604 Is this a noncontrast CT?
# 1605 Is this a pneumonia vs. pleural effusion?
# 1606 Is a pneumonia or pleural effusion seen in this image?
# 1607 Is/Are the sulci abnormal?
# 1608 Is/Are the sulci abnormal?
# 1609 Is there deviation in the trachea?
# 1610 Is there tracheal deviation?
# 1611 Is there tracheal deviation?
# 1612 Is there tracheal deviation?
# 1613 Is the pathology seen hyperintense or hypointense in nature?
# 1614 Is the abnormality hyperintense or hypointense?
# 1615 Do you see cardiomegaly?
# 1616 Is the heart enlarged?
# 1617 Is cardiomegaly present?
# 1618 Is the heart enlarged?
# 1619 Is this an axial plane image?
# 1620 Is this a KUB film?
# 1621 Is a noncontrast CT the first imaging test for a suspected brain bleed?
# 1622 Is the heart size abnormal?
# 1623 Is/Are the ventricles an abnormal size?
# 1624 Is/Are the ventricles an abnormal size?
# 1625 Is there tracheal deviation?
# 1626 Is there tracheal deviation?
# 1627 Are there any abnormalities seen in the spleen?
# 1628 Is the spleen abnormal?
# 1629 Are there pleural effusions present?
# 1630 Is/Are there pleural effusions?
# 1631 Is there presence of pleural effusions in this patient?
# 1632 Is/Are there pleural effusions?
# 1633 Is this an MRI image?
# 1634 Is this film taken AP?
# 1635 Are there any abnormalities in the kidneys?
# 1636 Is/Are the kidneys abnormal?
# 1637 Notice any abnormality in the kidneys?
# 1638 Is/Are the kidneys abnormal?
# 1639 Is this a plain film xray?
# 1640 Are the costophrenic angles blunted?
# 1641 Is there any blunting of the costophrenic angle(s)?
# 1642 Any tracheal deviation present?
# 1643 Is/Are there tracheal deviation?
# 1644 Is there any presence of tracheal deviation?
# 1645 Is/Are there tracheal deviation?
# 1646 Is this image a CT or MRI image?
# 1647 Is this a special kind of X-ray?
# 1648 Is the heart enlarged?
# 1649 Is the heart enlarged?
# 1650 Is this a sagittal plane image?
# 1651 Is there evidence of left lung field hyperinflation?
# 1652 Has the left lung collapsed?
# 1653 Is/Are there collapse in the patient's left lung?
# 1654 Is the grey/white matter border well differentiated?
# 1655 Is there blurring of the grey-white matter junction?
# 1656 Is/Are there blurring in the patient's grey-white matter?
# 1657 Does the pancreatic head appear enlarged?
# 1658 Is/Are the pancreatic head large?
# 1659 Is the size of the pancreatic head large?
# 1660 Is/Are the pancreatic head large?
# 1661 Is there evidence of mediastinal shift?
# 1662 Is/Are there are midline shift?
# 1663 Is there a midline shift?
# 1664 Is/Are there are midline shift?
# 1665 Is there evidence of hilar enlargement?
# 1666 Is/Are the hilum enlargement?
# 1667 Is there increased lung markings near the hilum?
# 1668 Is/Are the hilum enlargement?
# 1669 Is the mass compressing the inferior vena cava?
# 1670 Is/Are there compression in the patient's inferior vena cava?
# 1671 Is the inferior vena cava compressed by the tumor?
# 1672 Is/Are there compression in the patient's inferior vena cava?
# 1673 Are the kidneys normal?
# 1674 Is this image normal?
# 1675 Are these normal looking kidneys?
# 1676 Is this image normal?
# 1677 Is the right costophrenic angle sharp?
# 1678 Is/Are the R costophrenic angle sharp?
# 1679 Is the right costophrenic angle easily visualized?
# 1680 Is/Are the R costophrenic angle sharp?
# 1681 Are the ventricles symmetrical?
# 1682 Is/Are the ventricles symmetric? -yes/no
# 1683 Are the ventricles the same size?
# 1684 Is/Are the ventricles symmetric? -yes/no
# 1685 Is free air present under the patient's left or right hemidiaphragm?
# 1686 Are any ventricles visualized on this image?
# 1687 Can you see ventricles?
# 1688 Are there any other organs visualized in this image?
# 1689 Are both kidneys visualized?
# 1690 Can you see both kidneys in this image?
# 1691 Is there evidence of calcification in the pancreas?
# 1692 Is there calcification in the patient's pancreas?
# 1693 Is the pancreas calcified?
# 1694 Is/Are the pancreas calcified? -yes/no
# 1695 Is the heart displaced?
# 1696 Is the heart in the wrong position?
# 1697 Is there hyperinflation of the lung(s)?
# 1698 Is/Are there lung hyperinflation?
# 1699 Are the lungs increased in size?
# 1700 Is/Are there lung hyperinflation?
# 1701 Is there an aortic aneurysm?
# 1702 Is/Are there an aortic aneurysm?
# 1703 Can an aortic aneurysm be appreciated?
# 1704 Is/Are there an aortic aneurysm?
# 1705 Is mass effect obvious?
# 1706 Is/Are there Mass effect?
# 1707 Does there seem to be a mass effect?
# 1708 Is/Are there Mass effect?
# 1709 Is there a midline shift?
# 1710 Is/Are there midline shift?
# 1711 Is the trachea shifted?
# 1712 Is/Are there midline shift?
# 1713 Is the vertebra fractured?
# 1714 Is/Are there a vertebral fracture?
# 1715 Is there a vertebral fracture?
# 1716 Is/Are there a vertebral fracture?
# 1717 Is the trachea deviated to the right or left?
# 1718 Where is/are the trachea located?
# 1719 Do you suspect vascular process or a genetic process?
# 1720 Is the etiology genetic or vascular?
# 1721 can this patient be managed with medical therapy alone?
# 1722 Will medical therapy be enough?
# 1723 Is this a vascular lesion
# 1724 Does this lesion involve the vascular system?
# 1725 is there wall enhancement of the GB?
# 1726 Is/Are there enhancement in the patient's gallbladder wall?
# 1727 Is the gallbladder wall enhanced by contrast?
# 1728 Is/Are there enhancement in the patient's gallbladder wall?
# 1729 Are the lymph nodes enlarged
# 1730 Is/Are there hilar lymphadenopathy?
# 1731 Is there hilar lymphadenopathy?
# 1732 Is/Are there hilar lymphadenopathy?
# 1733 Is this a tension pneumothorax?
# 1734 Is/Are there a tension pneumothorax?
# 1735 Does this image show a tension pneumothorax?
# 1736 Is/Are there a tension pneumothorax?
# 1737 Is there a pancreatic pseudocsyst?
# 1738 Is/Are there a pseudocyst in the patient's pancreas?
# 1739 Is there a pseudocyst in the pancreas?
# 1740 Is/Are there a pseudocyst in the patient's pancreas?
# 1741 is there tracheal deviation?
# 1742 Is/Are there tracheal deviation?
# 1743 Is the trachea deviated?
# 1744 Is/Are there tracheal deviation?
# 1745 Would you expect pleural plaques on other pleural surfaces vs just the hemithoraces?
# 1746 Do you expect the patient to have plaques on other pleura as well?
# 1747 Is gray or white matter highlighted in this image?
# 1748 Which is highlighted in this image, white or gray matter?
# 1749 Do the two findings have the same etiology?
# 1750 Is there a unified process?
# 1751 Are there any abnormalities with the shape of the aortic arch?
# 1752 Is/Are the aortic arch normal?
# 1753 Is the aortic arch shape abnormal?
# 1754 Is/Are the aortic arch normal?
# 1755 Is the patient's heart enlarged?
# 1756 Is/Are the the heart enlarged ?
# 1757 Does the heart look enlarged?
# 1758 Is/Are the the heart enlarged ?
# 1759 Is there any bleeding in this patient's brain?
# 1760 Is/Are the there bleeding  located near/in the patient's brain ?
# 1761 Is there bleeding present in this patient's brain?
# 1762 Is/Are the there bleeding  located near/in the patient's brain ?
# 1763 Does the patient have ascites?
# 1764 Is/Are there ascites present ?
# 1765 Is there ascites present?
# 1766 Is/Are there ascites present ?
# 1767 Can gray-white differentiation be well assessed with this image?
# 1768 Is there significant difference between gray and white matter here?
# 1769 Is the occipital lobe visible in this image?
# 1770 Is/Are there the occipital lobe?
# 1771 Is the occipital lobe present?
# 1772 Is/Are there the occipital lobe?
# 1773 Is there infiltrate in the sinuses?
# 1774 Are the sinuses abnormal?
# 1775 Is/Are the sinuses abnormal?
# 1776 Is cerebral cortex present in this image?
# 1777 Can the cerebral cortex be visualized at this level?
# 1778 Is the hyperinflation unilateral or bilateral?
# 1779 Is the lung hyperinflated on one or both sides?
# 1780 Are the lines seen on the exterior or interior of the patient?
# 1781 Are the lines in the image inside or outside of the patient?
# 1782 Are the lungs clear?
# 1783 Is/Are the lungs clear? -yes/no
# 1784 Are there lungs free of consolidation?
# 1785 Is there fat stranding?
# 1786 Is/Are there fat stranding?
# 1787 Is fat stranding present?
# 1788 Is/Are there fat stranding?
# 1789 Do the lungs appear hyperinflated?
# 1790 Is/Are there hyperinflation?
# 1791 Is hyperinflation depicted?
# 1792 Is/Are there hyperinflation?
# 1793 Is the bowel distended?
# 1794 Is/Are there bowel distension?
# 1795 Is bowel distension present?
# 1796 Is/Are there bowel distension?
# 1797 Is the cardiac silhouette enlarged?
# 1798 Is cardiomegaly present?
# 1799 Is there fat stranding present?
# 1800 Is/Are there fat stranding?
# 1801 Is fat stranding depicted in this image?
# 1802 Is/Are there fat stranding?
# 1803 Is the mass in the liver regular or irregular in contour?
# 1804 How would you describe the liver mass?
# 1805 Is there a midline shift?
# 1806 Is there midline shift?
# 1807 Is there structural deviation from the midline?
# 1808 Is there midline shift?
# 1809 Is the circular opacity (located in the middle of this image) found on top of the patient or within the patient?
# 1810 Where is/are the circular opacity located?
# 1811 Is the opacity located in the middle of the image inside the patient or superficial to the patient's skin?
# 1812 Where is/are the circular opacity located?
# 1813 Is there decreased aeration at the apex?
# 1814 Is the apical aeration normal or decreased?
# 1815 Is this a T1 weighted, T2 weighted, or FLAIR image?
# 1816 What is/are the image weighting of the MRI?
# 1817 Is this image modality T1, T2, or FLAIR?
# 1818 What is/are the image weighting of the MRI?
# 1819 Is this a PA film?
# 1820 Is this film taken in a PA modality?

# %% [markdown]
# <a id="t1."></a>
# # **PART: 2 Loading and Preparaing the dataset for the Model:**
#
# * So, we have saved each of the question vector and answer vector in a .h5 file
# * Now according to [slides](http://www.cs.virginia.edu/~vicente/vislang/slides/wasimonica.pdf), we need to convert the image into a 448 * 448 * 3 images, and then pass it through some preprocessing layers to convert into 14 * 14 * 512 (which will be reshaped to 196 * 512, where each region will be 1 * 1* 512)
# * For preprocessing the image, we would use the VGG16 preprocessing layer, which would help in coverting the image to 14 * 14 * 512 dimension ( will be applied while building the model)

# %%
import json
import h5py
import numpy as np
import copy
from random import shuffle, seed
import sys
import os.path
import argparse
import glob
import numpy as np
import scipy.io
import pdb
import string
import h5py
import nltk
from nltk.tokenize import word_tokenize
import gensim
import json
import re
import cv2
import tensorflow as tf
import numpy as np
import keras
import pandas as pd
import os
import matplotlib.pyplot as plt
dropout_rate = 0.4
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# -------------------------------------------------------------------------------------------------------------
# The below part is same as that of part 1

def extract_feat(doc):
    feat = []
    for word in doc:
        try:
            feat.append(model_w2v[word])
        except:
            pass
    return feat

def tokenize(sentence):
    return [i for i in re.split(r"([-.\"',:? !\$#@~()*&\^%;\[\]/\\\+<>\n=])", sentence) if i!='' and i!=' ' and i!='\n'];

def prepro_question(imgs, method):
  
    # preprocess all the question
    print('example processed tokens:')
    for i,img in enumerate(imgs):
        s = img['question'].lower()
        if method == 'nltk':
            txt = word_tokenize(str(s).lower())
        else:
            txt = tokenize(s)
        img['processed_tokens'] = txt
        if i < 10: print(txt)
        if i % 1000 == 0:
            sys.stdout.write("processing %d/%d (%.2f%% done)   \r" %  (i, len(img), i*100.0/len(imgs)) )
            sys.stdout.flush()   
    return imgs

def get_top_answers(imgs, num_ans):
    counts = {}
    for img in imgs:
        try:
            ans = img['answer'].lower() 
        except :
            ans = str(img['answer'])
        counts[ans] = counts.get(ans, 0) + 1 # Frequency count

    cw = sorted([(count,w) for w,count in counts.items()], reverse=True)
    # print('top answer and their counts:') 
    # print('\n'.join(map(str,cw[:20])))
    
    vocab = []
    for i in range(min(num_ans,len(cw))):
        vocab.append(cw[i][1])

    return vocab[:num_ans]


def filter_question(imgs, atoi):
    new_imgs = []
    for i, img in enumerate(imgs):
            new_imgs.append(img)

    print('question number reduce from %d to %d '%(len(imgs), len(new_imgs)))
    return new_imgs
# Old Part finishes
# ---------------------------------------------------------------------------------------------------------------------
# New part starts
# -------------------------------------------------------------------------------------------------------------------
def image_layer(input_shape):
    '''
    Input : Shape of the image
    Output : VGG16 Preprocessing model
    '''
    base_model = tf.keras.applications.VGG16(input_shape=input_shape, include_top=False,weights='imagenet')
    base_model.trainable = False # Do not train it
    x = base_model.layers[-2].output  # Shape would be (28*28*512)
    x = tf.reshape(x , [-1,x.shape[2]*x.shape[1] , x.shape[3]]) # Shape would be (1,784,512)
    x = tf.keras.layers.Dense(1024) # This step can be found out in the slides, that after feature extraction, they are connecting a dense layer, slide - 6 (Transform into a same size vector)
    return x

def vgg_preprocessing(model,image):
  ''' Takes a tensor as an input, and returns a pre processed version of the image'''
  return model(image)

def load_data():

  '''
  Input: Nothing

  Output: Returns list containing the following four elements in a tuple
  (preprocessed version of the image,embedded question,embedded answer, question id)
  '''

  images = []
  questions = []
  answers = []
  ids = []
        
  #print(start,end)
  #arrs = np.random.randint(0,len(imgs_data_train),batch)
  #data = [imgs_data_train[i] for i in arrs]
        
  data = imgs_data_train   # trainset_closed.json
  model = image_layer(input_shape = (448,448,3)) # Making VGG16 Model
  for i,img in enumerate(data):
        
      img_path = img['image_name']  # Image Name
      question_id = img['qid']      # Question id

      #label_arrays = np.zeros((1, max_length, feat_dim), dtype='float32') # Somethings are taken directly from 
            
      with h5py.File(os.path.join(dir_path,str(question_id) + '.h5'),'r') as hf:
        question = hf['ques_train'][()] # Embedded question
        answer = hf['answers'][()]      # Embedded answer

      # print(question, answer)
      image = cv2.imread(os.path.join('./../VQA_RAD Image Folder',img_path) , cv2.IMREAD_COLOR) # Reading the image
      image = cv2.cvtColor(image , cv2.COLOR_BGR2RGB)
      image = cv2.resize(image , (448,448)) # Reshape

      '''
      Small Note : I had not applied the VGG Preprocessing here, because I wanted to use the original shape of 448, and then, I would 
      attach the VGG Model, while making the model, I think this makes sense :)
      '''
      #image = vgg_preprocessing(model,image)
      # Apply VGG16 Preprocessings

      images.append(image)
      questions.append(np.array(question))
      answers.append(np.array(answer))
      ids.append(question_id)     
      if i%100==0:
        print("Processed =>",i,' which is',round(100*i/len(data),2),'%')          
        
  questions = np.reshape(np.array(questions) , [-1,max_length,feat_dim])
  return (np.array(images) , questions ,np.array(answers) , np.array(ids))

imgs_train = json.load(open('./trainset_closed.json' , 'r'))
num_ans = 1000
top_ans = get_top_answers(imgs_train, num_ans )
atoi = {w:i for i,w in enumerate(top_ans)}
itoa = {i:w for i,w in enumerate(top_ans)}
feat_dim = 300
imgs_data_train = json.load(open('./trainset_closed.json' , 'r'))
num_ans = 10
method = 'nltk'
max_length = 21
dir_path = "./QA"
N = len(imgs_data_train)

# ---------------------------------------------------------------------------------------
# New part finishes

# %%
import tensorflow as tf
import numpy as np
import keras,h5py
import pandas as pd
import os
import json
from tqdm import tqdm 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from keras.applications.vgg16 import VGG16
import keras.activations
import keras.backend as kbe
from keras.callbacks import EarlyStopping
import tensorflow.keras.layers as layers
from keras.layers import Activation, Add, Concatenate, Conv1D, Dense, Dropout, Embedding, Softmax
from keras.layers import Input, GlobalMaxPooling1D, Lambda, Multiply, RepeatVector, Reshape
from keras.layers import BatchNormalization 
from keras.models import Model
from keras.regularizers import l2
import pickle
from pprint import pprint

''' These parameters are for some of the previous attempts, so ignore it, the main part is : datagen = load_data(), and I don't want to remove all of these,
because indeed there can be some ideas coming out from these lines of code'''

embed_size = 300
q_len = 21
height = 224
width = 224
lstm_units = 256
attention_dim = 512
num_output = 1000
max_questions = 3064

batch_size = 32
lr = 0.001
articles = ['a', 'an', 'the']
manualMap = { 'none': '0', 'zero': '0', 'one': '1', 'two': '2', 'three':
                  '3', 'four': '4', 'five': '5', 'six': '6', 'seven': '7',
                  'eight': '8', 'nine': '9', 'ten': '10' }


datagen = load_data()   # Load the Data
# Out:
# Processed => 0  which is 0.0 %
# Processed => 100  which is 5.49 %
# Processed => 200  which is 10.98 %
# Processed => 300  which is 16.47 %
# Processed => 400  which is 21.97 %
# Processed => 500  which is 27.46 %
# Processed => 600  which is 32.95 %
# Processed => 700  which is 38.44 %
# Processed => 800  which is 43.93 %
# Processed => 900  which is 49.42 %
# Processed => 1000  which is 54.91 %
# Processed => 1100  which is 60.41 %
# Processed => 1200  which is 65.9 %
# Processed => 1300  which is 71.39 %
# Processed => 1400  which is 76.88 %
# Processed => 1500  which is 82.37 %
# Processed => 1600  which is 87.86 %
# Processed => 1700  which is 93.36 %
# Processed => 1800  which is 98.85 %

# %% [markdown]
# ### Creating the Dataset: We do this, by renaming the contents of .h5 file

# %%
from tqdm import tqdm

# %%
images,questions,answers,ids =datagen[0],datagen[1],datagen[2],datagen[3]
print("Images have a size of:",images.shape)
print("Questions have a size of:",questions.shape)
print("Answers have a size of:",answers.shape)
print("Ids have a size of:",ids.shape)
dir_path = r"./QA" # The directory where the .h5 file for each entry is saved
print(dir_path)
m = 100
for i in tqdm(range(images.shape[0])):

    filename = os.path.join( dir_path , str(ids[i])) + '.h5'

    with h5py.File(filename,'r+') as f:
      f.create_dataset("quest1_train", dtype='float32', data=questions[i]) # Question Embedding
      f.create_dataset("imaget1_vector", dtype='float32', data=images[i]) # Image Embedding (Not preprocessed)
      f.create_dataset("answerst1", dtype='uint32', data=answers[i])      # Answers in embedded form
      # Check if file is already open

    if i%m ==0:
        print("Processed =>", i,' total percentage =>', round(100*i/images.shape[0],2),' %')
print("Your processing has been done")
# Out:
# Images have a size of: (1821, 448, 448, 3)
# Questions have a size of: (1821, 21, 300)
# Answers have a size of: (1821,)
# Ids have a size of: (1821,)
# ./QA
#   2%|▏         | 39/1821 [00:00<00:05, 354.46it/s]
# Processed => 0  total percentage => 0.0  %
#   8%|▊         | 147/1821 [00:00<00:04, 345.25it/s]
# Processed => 100  total percentage => 5.49  %
#  14%|█▎        | 249/1821 [00:00<00:05, 311.18it/s]
# Processed => 200  total percentage => 10.98  %
#  19%|█▉        | 345/1821 [00:01<00:04, 295.63it/s]
# Processed => 300  total percentage => 16.47  %
#  24%|██▍       | 441/1821 [00:01<00:04, 296.96it/s]
# Processed => 400  total percentage => 21.97  %
#  29%|██▉       | 528/1821 [00:01<00:05, 245.94it/s]
# Processed => 500  total percentage => 27.46  %
#  34%|███▍      | 626/1821 [00:02<00:05, 214.00it/s]
# Processed => 600  total percentage => 32.95  %
#  41%|████      | 738/1821 [00:02<00:05, 213.05it/s]
# Processed => 700  total percentage => 38.44  %
#  46%|████▋     | 844/1821 [00:03<00:04, 204.45it/s]
# Processed => 800  total percentage => 43.93  %
#  51%|█████▏    | 934/1821 [00:03<00:04, 210.89it/s]
# Processed => 900  total percentage => 49.42  %
#  56%|█████▌    | 1017/1821 [00:04<00:04, 179.75it/s]
# Processed => 1000  total percentage => 54.91  %
#  61%|██████▏   | 1117/1821 [00:04<00:04, 161.43it/s]
# Processed => 1100  total percentage => 60.41  %
#  68%|██████▊   | 1230/1821 [00:05<00:03, 149.33it/s]
# Processed => 1200  total percentage => 65.9  %
#  73%|███████▎  | 1323/1821 [00:06<00:03, 134.20it/s]
# Processed => 1300  total percentage => 71.39  %
#  78%|███████▊  | 1416/1821 [00:06<00:02, 144.24it/s]
# Processed => 1400  total percentage => 76.88  %
#  84%|████████▎ | 1521/1821 [00:07<00:02, 138.21it/s]
# Processed => 1500  total percentage => 82.37  %
#  89%|████████▊ | 1613/1821 [00:08<00:01, 141.77it/s]
# Processed => 1600  total percentage => 87.86  %
#  94%|█████████▍| 1719/1821 [00:09<00:00, 142.61it/s]
# Processed => 1700  total percentage => 93.36  %
# 100%|██████████| 1821/1821 [00:09<00:00, 184.01it/s]
# Processed => 1800  total percentage => 98.85  %
# Your processing has been done

# %% [markdown]
# <a id="t2."></a>
# # **PART: 3 Making the Model**  ( START RUNNING FROM THIS CELL, IF YOU HAVE ALREADY RAN IT ONCE, AND IS RUNING AGAIN)
# So, we go by the following rule:
#
# 1. Pre-process the image (making it (None,196,512)), where 196 represents 196 regions, wach of 32 * 32 pixel
# 2. Make it of the same size of that of question embedding
# 3. Now, we will pass the ques layer through LSTM, and pass preprocessed image through dense network (activation is tanh),  of SAN, where they used Dense network with tanh activation, and hence we would do the same
# 4. Then, we will concatenate both the vectors, and then, pass through dense layers, and final layer with softmax function
# 5. The loss function is Sparse Categorical Cross Entropy, optimizer is Adam with learning rate of 0.01, and batch size of 32, and for 50 epochs

# %%
# link - http://www.cs.virginia.edu/~vicente/vislang/slides/wasimonica.pdf
import os,h5py
# Image Model
import tensorflow as tf
import numpy as np
from tqdm import tqdm
from tensorflow.keras import Model
import warnings
warnings.filterwarnings('ignore')

'''  Preprocessing with the VGG 16 Model  '''

model = tf.keras.applications.VGG16(include_top=False,weights='imagenet',
        input_shape=(448,448,3))
#print("The Last layer")
last_layer = model.layers[-1].output   # Last layer has an output layer of (14,14,512)
model = Model(model.input,last_layer)
model.trainable = False
# print(model.summary())
def extract_feature(image):
    ''' Preprocessing with VGG Netowrk'''
    image = model(image)
    return image  # Shape is (196,512)

'''  The below model will convert (196,512) to (21,300) (i.e same as the dimension of word embedding)  '''

dimen_red = tf.keras.Sequential()  # Use for converting (196,512) -> (21,300)
dimen_red.add(tf.keras.layers.Conv2D(300,kernel_size=(1,1),input_shape= (14,14,512)))
dimen_red.add(tf.keras.layers.Reshape((196,300)))
dimen_red.add(tf.keras.layers.Permute((2,1)))  # Reshaping about the axis, useful for applying the dense network
dimen_red.add(tf.keras.layers.Dense(21))
dimen_red.add(tf.keras.layers.Permute((2,1)))  # Reshaping about the axis, useful for applying the dense network

train_dir = r"./QA/" # Containing .h5 file
images = []
answers = []
questions = []
count = 0
content = os.listdir(train_dir)   # The GPU Memory became full after this, hence had to take just these much samples :(
length = len(content)
batch_size = 8
num_batches = int(np.ceil(len(content) / batch_size))

for batch_idx in tqdm(range(num_batches)):
    batch_start = batch_idx * batch_size
    batch_end = min(batch_start + batch_size, len(content))
    batch_files = content[batch_start:batch_end]

    # Loop over the HDF5 files in the current batch and read the data
    for i in batch_files:
        file = h5py.File(train_dir + i, 'r')
        images.append(np.array(file['imaget1_vector'][()]))
        answers.append(np.array(file['answerst1'][()]))
        questions.append(np.array(file['quest1_train'][()]))

        file.close()

        # Print progress every 100 files
        if len(images) % 100 == 0:
            print(f"Processed {len(images)} files")

# Convert the data to TensorFlow tensors
images = tf.convert_to_tensor(np.array(images))
answers = tf.convert_to_tensor(np.array(answers))
questions = tf.convert_to_tensor(np.array(questions))
# Out:
#   8%|▊         | 18/228 [00:00<00:04, 42.37it/s]
# Processed 100 files
#  12%|█▏        | 28/228 [00:00<00:05, 37.04it/s]
# Processed 200 files
#  18%|█▊        | 40/228 [00:01<00:07, 26.32it/s]
# Processed 300 files
#  23%|██▎       | 52/228 [00:01<00:07, 24.25it/s]
# Processed 400 files
#  28%|██▊       | 64/228 [00:02<00:07, 21.15it/s]
# Processed 500 files
#  33%|███▎      | 76/228 [00:02<00:07, 20.33it/s]
# Processed 600 files
#  39%|███▉      | 89/228 [00:03<00:07, 18.98it/s]
# Processed 700 files
#  46%|████▌     | 105/228 [00:04<00:04, 26.97it/s]
# Processed 800 files
#  51%|█████▏    | 117/228 [00:04<00:03, 27.79it/s]
# Processed 900 files
#  55%|█████▌    | 126/228 [00:05<00:05, 19.68it/s]
# Processed 1000 files
#  61%|██████▏   | 140/228 [00:06<00:05, 16.21it/s]
# Processed 1100 files
#  67%|██████▋   | 153/228 [00:06<00:03, 20.55it/s]
# Processed 1200 files
#  72%|███████▏  | 165/228 [00:07<00:02, 22.18it/s]
# Processed 1300 files
#  78%|███████▊  | 177/228 [00:07<00:02, 22.13it/s]
# Processed 1400 files
#  83%|████████▎ | 189/228 [00:08<00:01, 22.80it/s]
# Processed 1500 files
#  88%|████████▊ | 201/228 [00:08<00:01, 21.73it/s]
# Processed 1600 files
#  95%|█████████▍| 216/228 [00:09<00:00, 22.28it/s]
# Processed 1700 files
# 100%|██████████| 228/228 [00:10<00:00, 22.43it/s]
# Processed 1800 files

# %%
# pd.DataFrame(np.array(images)).to_csv('Images')
# pd.DataFrame(np.array(questions)).to_csv('Questions')
# pd.DataFrame(np.array(answers)).to_csv('Answers')

# %%
# l = []
# length = np.array(images).shape[0]
# for i,img in enumerate(images):
#   l.append(model(img.reshape(1,448,448,3)))  # It was not possible directly on GPU, hence had to use for loop
#   if i%100 ==0:
#     print("The count is:",i,"and the percentage proportion is:",round(100*i/length,2),'%')
# images = tf.convert_to_tensor(np.array(l) )
import tensorflow as tf
import numpy as np

l = []
length = np.array(images).shape[0]
for i, img in enumerate(images):
    img = tf.reshape(img, (1, 448, 448, 3))
    l.append(model(img))  # Assuming `model` is a TensorFlow model

    if i % 100 == 0:
        print("The count is:", i, "and the percentage proportion is:", round(100 * i / length, 2), '%')

images = tf.convert_to_tensor(np.array(l))
# Out:
# The count is: 0 and the percentage proportion is: 0.0 %
# The count is: 100 and the percentage proportion is: 5.49 %
# The count is: 200 and the percentage proportion is: 10.98 %
# The count is: 300 and the percentage proportion is: 16.47 %
# The count is: 400 and the percentage proportion is: 21.97 %
# The count is: 500 and the percentage proportion is: 27.46 %
# The count is: 600 and the percentage proportion is: 32.95 %
# The count is: 700 and the percentage proportion is: 38.44 %
# The count is: 800 and the percentage proportion is: 43.93 %
# The count is: 900 and the percentage proportion is: 49.42 %
# The count is: 1000 and the percentage proportion is: 54.91 %
# The count is: 1100 and the percentage proportion is: 60.41 %
# The count is: 1200 and the percentage proportion is: 65.9 %
# The count is: 1300 and the percentage proportion is: 71.39 %
# The count is: 1400 and the percentage proportion is: 76.88 %
# The count is: 1500 and the percentage proportion is: 82.37 %
# The count is: 1600 and the percentage proportion is: 87.86 %
# The count is: 1700 and the percentage proportion is: 93.36 %
# The count is: 1800 and the percentage proportion is: 98.85 %

# %%
l = []
length = images.shape[0]
for i,j in enumerate(images):
  l.append(dimen_red(j))     # Making it to the same shape as that of question embedding
  if i%100 ==0:
    print("The count is:",i,"and the percentage proportion is:",round(100*i/length,2),'%')
images = tf.convert_to_tensor(np.array(l))
# Out:
# The count is: 0 and the percentage proportion is: 0.0 %
# The count is: 100 and the percentage proportion is: 5.49 %
# The count is: 200 and the percentage proportion is: 10.98 %
# The count is: 300 and the percentage proportion is: 16.47 %
# The count is: 400 and the percentage proportion is: 21.97 %
# The count is: 500 and the percentage proportion is: 27.46 %
# The count is: 600 and the percentage proportion is: 32.95 %
# The count is: 700 and the percentage proportion is: 38.44 %
# The count is: 800 and the percentage proportion is: 43.93 %
# The count is: 900 and the percentage proportion is: 49.42 %
# The count is: 1000 and the percentage proportion is: 54.91 %
# The count is: 1100 and the percentage proportion is: 60.41 %
# The count is: 1200 and the percentage proportion is: 65.9 %
# The count is: 1300 and the percentage proportion is: 71.39 %
# The count is: 1400 and the percentage proportion is: 76.88 %
# The count is: 1500 and the percentage proportion is: 82.37 %
# The count is: 1600 and the percentage proportion is: 87.86 %
# The count is: 1700 and the percentage proportion is: 93.36 %
# The count is: 1800 and the percentage proportion is: 98.85 %

# %%
images = tf.reshape(images,[length,21,300])
img = images  #Tensor containing images
que = questions  # Tensor containing question vector
img = img/255.0 # Normalizing

# %%
np.array(que).shape,np.array(img).shape,np.array(answers).shape
# Out:
# ((1821, 21, 300), (1821, 21, 300), (1821,))

# %%
''' The below mentioned two Input objects of keras will be useful for making the model '''

ques = tf.keras.layers.Input((21,300))  # Input Model (for ques)
images = tf.keras.layers.Input((21,300)) # Input Model (for images)

# %%
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, LSTM, GlobalMaxPooling1D, SpatialDropout1D,Flatten,Concatenate,MultiHeadAttention

''' Imagica is for the preprocessing of the image part'''
imagica = Dense(512,activation='tanh')(images)
imagica = Dense(512,activation='tanh')(images)


''' quesa is for the ques layer, which means preprocessing of the question layer'''
quesa = LSTM(512, dropout = 0.3,return_sequences = True,input_shape = (21,300))(ques)
quesa = Dense(512, activation = 'relu')(quesa)
quesa = Dropout(0.3)(quesa)
quesa = Dense(512, activation = 'relu')(quesa)
quesa = Dropout(0.3)(quesa)

''' Concatenating both image and the question layer'''
# quesa = Concatenate()([quesa,imagica])
# quesa = Flatten()(quesa)
num_attention_heads = 4
key_dim = 32


quesa = Concatenate()([quesa, imagica])

# %%
np.array(que).shape,np.array(img).shape,np.array(answers).shape
# Out:
# ((1821, 21, 300), (1821, 21, 300), (1821,))

# %%
from keras.layers import Dense, Dropout, Embedding, LSTM, GlobalMaxPooling1D, SpatialDropout1D,Flatten,Concatenate,Attention

quesa = Flatten()(quesa)
out = tf.keras.layers.Dense(tf.keras.utils.to_categorical(answers).shape[1],activation='softmax')(quesa) # Final output has 476 different categories, you can check by finding length of uniquue answers :)

# %% [markdown]
# ## Plotting the Model

# %%
from keras.utils.vis_utils import plot_model
model = Model([ques,images],[out])
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ## Compiling and fitting the model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.01),loss ='categorical_crossentropy',metrics=['accuracy'])
# from tensorflow.keras import metrics

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.01),loss ='categorical_crossentropy',metrics=[metrics.mean_absolute_error])

# %%
answers.shape
# Out:
# TensorShape([1821])

# %%
answers = tf.keras.utils.to_categorical(answers)

# %%
answers.shape
# Out:
# (1821, 57)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 21, 300)]    0           []
#
#  lstm (LSTM)                    (None, 21, 512)      1665024     ['input_5[0][0]']
#
#  dense_6 (Dense)                (None, 21, 512)      262656      ['lstm[0][0]']
#
#  dropout (Dropout)              (None, 21, 512)      0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 21, 512)      262656      ['dropout[0][0]']
#
#  input_6 (InputLayer)           [(None, 21, 300)]    0           []
#
#  dropout_1 (Dropout)            (None, 21, 512)      0           ['dense_7[0][0]']
#
#  dense_5 (Dense)                (None, 21, 512)      154112      ['input_6[0][0]']
#
#  concatenate (Concatenate)      (None, 21, 1024)     0           ['dropout_1[0][0]',
#                                                                   'dense_5[0][0]']
#
#  flatten (Flatten)              (None, 21504)        0           ['concatenate[0][0]']
#
#  dense_8 (Dense)                (None, 57)           1225785     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 3,570,233
# Trainable params: 3,570,233
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
np.array(answers).shape,np.array(img).shape,np.array(que).shape
# Out:
# ((1821, 57), (1821, 21, 300), (1821, 21, 300))

# %%
answers.shape,np.array(img).shape,np.array(que).shape
# Out:
# ((1821, 57), (1821, 21, 300), (1821, 21, 300))

# %%
answers.shape,np.array(img).shape,np.array(que).shape
# history = model.fit([np.array(img),np.array(que)],np.array(answers),epochs = 50,batch_size=32,verbose=1)
# Out:
# ((1821, 57), (1821, 21, 300), (1821, 21, 300))

# %% [markdown]
# ## Saving the Model and analysing the prediction

# %%
history = model.fit([np.array(img),np.array(que)],np.array(answers),epochs = 50,batch_size=32,verbose=1)
# Out:
# Epoch 1/50
# 57/57 [==============================] - 16s 227ms/step - loss: 1.9818 - accuracy: 0.5360
# Epoch 2/50
# 57/57 [==============================] - 13s 232ms/step - loss: 1.0956 - accuracy: 0.6568
# Epoch 3/50
# 57/57 [==============================] - 13s 234ms/step - loss: 1.0912 - accuracy: 0.6875
# Epoch 4/50
# 57/57 [==============================] - 14s 247ms/step - loss: 1.4884 - accuracy: 0.6886
# Epoch 5/50
# 57/57 [==============================] - 12s 208ms/step - loss: 1.5018 - accuracy: 0.7194
# Epoch 6/50
# 57/57 [==============================] - 13s 220ms/step - loss: 1.2020 - accuracy: 0.7375
# Epoch 7/50
# 57/57 [==============================] - 13s 223ms/step - loss: 1.0085 - accuracy: 0.7776
# Epoch 8/50
# 57/57 [==============================] - 12s 214ms/step - loss: 1.0612 - accuracy: 0.7699
# Epoch 9/50
# 57/57 [==============================] - 12s 212ms/step - loss: 1.2513 - accuracy: 0.7606
# Epoch 10/50
# 57/57 [==============================] - 11s 199ms/step - loss: 1.2872 - accuracy: 0.7814
# Epoch 11/50
# 57/57 [==============================] - 11s 192ms/step - loss: 1.2006 - accuracy: 0.8023
# Epoch 12/50
# 57/57 [==============================] - 11s 194ms/step - loss: 1.0901 - accuracy: 0.8072
# Epoch 13/50
# 57/57 [==============================] - 11s 199ms/step - loss: 1.2462 - accuracy: 0.7946
# Epoch 14/50
# 57/57 [==============================] - 11s 195ms/step - loss: 1.1699 - accuracy: 0.7930
# Epoch 15/50
# 57/57 [==============================] - 11s 192ms/step - loss: 1.4083 - accuracy: 0.7935
# Epoch 16/50
# 57/57 [==============================] - 11s 191ms/step - loss: 1.4262 - accuracy: 0.7941
# Epoch 17/50
# 57/57 [==============================] - 11s 197ms/step - loss: 1.2514 - accuracy: 0.8182
# Epoch 18/50
# 57/57 [==============================] - 11s 196ms/step - loss: 1.2509 - accuracy: 0.8309
# Epoch 19/50
# 57/57 [==============================] - 11s 199ms/step - loss: 1.2084 - accuracy: 0.8215
# Epoch 20/50
# 57/57 [==============================] - 13s 234ms/step - loss: 1.2521 - accuracy: 0.8237
# Epoch 21/50
# 57/57 [==============================] - 12s 212ms/step - loss: 0.9957 - accuracy: 0.8501
# Epoch 22/50
# 57/57 [==============================] - 12s 216ms/step - loss: 0.9843 - accuracy: 0.8512
# Epoch 23/50
# 57/57 [==============================] - 13s 226ms/step - loss: 0.9730 - accuracy: 0.8704
# Epoch 24/50
# 57/57 [==============================] - 13s 219ms/step - loss: 1.1024 - accuracy: 0.8468
# Epoch 25/50
# 57/57 [==============================] - 14s 238ms/step - loss: 0.9156 - accuracy: 0.8622
# Epoch 26/50
# 57/57 [==============================] - 12s 209ms/step - loss: 0.8222 - accuracy: 0.8666
# Epoch 27/50
# 57/57 [==============================] - 13s 231ms/step - loss: 0.9238 - accuracy: 0.8649
# Epoch 28/50
# 57/57 [==============================] - 13s 226ms/step - loss: 1.1471 - accuracy: 0.8666
# Epoch 29/50
# 57/57 [==============================] - 12s 208ms/step - loss: 0.9009 - accuracy: 0.8677
# Epoch 30/50
# 57/57 [==============================] - 12s 207ms/step - loss: 1.0464 - accuracy: 0.8622
# Epoch 31/50
# 57/57 [==============================] - 12s 209ms/step - loss: 1.0094 - accuracy: 0.8578
# Epoch 32/50
# 57/57 [==============================] - 12s 206ms/step - loss: 0.7680 - accuracy: 0.8677
# Epoch 33/50
# 57/57 [==============================] - 12s 205ms/step - loss: 0.8592 - accuracy: 0.8704
# Epoch 34/50
# 57/57 [==============================] - 12s 205ms/step - loss: 0.9484 - accuracy: 0.8638
# Epoch 35/50
# 57/57 [==============================] - 12s 203ms/step - loss: 0.9796 - accuracy: 0.8764
# Epoch 36/50
# 57/57 [==============================] - 12s 205ms/step - loss: 0.7706 - accuracy: 0.8792
# Epoch 37/50
# 57/57 [==============================] - 12s 204ms/step - loss: 0.8402 - accuracy: 0.8731
# Epoch 38/50
# 57/57 [==============================] - 12s 203ms/step - loss: 0.9418 - accuracy: 0.8715
# Epoch 39/50
# 57/57 [==============================] - 12s 208ms/step - loss: 0.8323 - accuracy: 0.8693
# Epoch 40/50
# 57/57 [==============================] - 12s 214ms/step - loss: 0.6989 - accuracy: 0.8836
# Epoch 41/50
# 57/57 [==============================] - 12s 206ms/step - loss: 0.6070 - accuracy: 0.8819
# Epoch 42/50
# 57/57 [==============================] - 12s 205ms/step - loss: 0.5099 - accuracy: 0.8979
# Epoch 43/50
# 57/57 [==============================] - 12s 206ms/step - loss: 0.6039 - accuracy: 0.8808
# Epoch 44/50
# 57/57 [==============================] - 11s 199ms/step - loss: 0.6900 - accuracy: 0.8885
# Epoch 45/50
# 57/57 [==============================] - 12s 203ms/step - loss: 1.0782 - accuracy: 0.8731
# Epoch 46/50
# 57/57 [==============================] - 11s 201ms/step - loss: 1.1845 - accuracy: 0.8578
# Epoch 47/50
# 57/57 [==============================] - 12s 209ms/step - loss: 0.9051 - accuracy: 0.8841
# Epoch 48/50
# 57/57 [==============================] - 11s 200ms/step - loss: 0.7905 - accuracy: 0.8935
# Epoch 49/50
# 57/57 [==============================] - 11s 195ms/step - loss: 0.6161 - accuracy: 0.8990
# Epoch 50/50
# 57/57 [==============================] - 11s 198ms/step - loss: 0.8942 - accuracy: 0.8748

# %%
plt.plot(history.history['loss'])
# plt.plot(history.history['accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
# plt.plot(history.history['accuracy'])
plt.title('model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')

# %% [markdown]
# ## END OF THE NOTEBOOK :)
